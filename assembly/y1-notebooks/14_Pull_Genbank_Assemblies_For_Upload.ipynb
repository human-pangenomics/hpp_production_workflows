# %% [markdown]
# # Notebook 14: Pull Genbank Assemblies For Upload<a class="tocSkip">
#
# **The final assemblies are up on Genbank, I will download them, put them in this workspace's bucket, then create a data table so we can run a workflow to change the header names and remove the soft masking.**
#
#
# **The steps that we will take are:**
# 1. Import Statements & Global Variable Definitions
# 2. Download NCBI Assemblies
# 3. Create Data Frame Of Assemblies
# 4. Copy Assemblies To Bucket
# 5. Upload To Data Table

# %% [markdown]
# # Import Statements & Global Variable Definitions

# %% [markdown]
# ## Load Python packages
# ----

# %%
# %%capture 
import terra_notebook_utils as tnu
import terra_pandas as tp
import os
import io
import gzip
import pandas as pd
import numpy as np

# %% [markdown]
# ## Set Environment Variables

# %%
# Get the Google billing project name and workspace name
PROJECT = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE = os.path.basename(os.path.dirname(os.getcwd()))
bucket = os.environ['WORKSPACE_BUCKET'] + "/"

# Verify that we've captured the environment variables
print("Billing project: " + PROJECT)
print("Workspace: " + WORKSPACE)
print("Workspace storage bucket: " + bucket)
# Out:
# Billing project: human-pangenome-ucsc
# Workspace: HPRC_Reassembly
# Workspace storage bucket: gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/

# %% [markdown]
# # Download NCBI Assemblies
# ## Install NCBI Datasets Tool

# %%
! wget https://ftp.ncbi.nlm.nih.gov/pub/datasets/command-line/LATEST/linux-amd64/datasets
# Out:
# --2021-06-21 02:31:36--  https://ftp.ncbi.nlm.nih.gov/pub/datasets/command-line/LATEST/linux-amd64/datasets
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 165.112.9.229, 130.14.250.13, 2607:f220:41e:250::12, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|165.112.9.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13075642 (12M)
# Saving to: ‘datasets’
#
# datasets            100%[===================>]  12.47M  44.4MB/s    in 0.3s
#
# 2021-06-21 02:31:37 (44.4 MB/s) - ‘datasets’ saved [13075642/13075642]

# %%
! chmod 777 datasets

# %% [markdown]
# ## Pull Dehydrated Zip File
# File is all of the assemblies in a dehydrated form from the NCBI datasets page. Need to unzip it then rehydrate

# %%
! mkdir final_assemblies
# %cd final_assemblies
# Out:
# mkdir: cannot create directory ‘final_assemblies’: File exists
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit/final_assemblies

# %%
! gsutil cp gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/genbank_assemblies/2021_06_20_Year1_Genbank_Assemblies_Dehydrated.zip ./
# Out:
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/genbank_assemblies/2021_06_20_Year1_Genbank_Assemblies_Dehydrated.zip...
# / [1 files][ 24.1 KiB/ 24.1 KiB]
# Operation completed over 1 objects/24.1 KiB.

# %%
! unzip 2021_06_20_Year1_Genbank_Assemblies_Dehydrated.zip -d y1_final_genbank
# Out:
# Archive:  2021_06_20_Year1_Genbank_Assemblies_Dehydrated.zip
#   inflating: y1_final_genbank/README.md
#   inflating: y1_final_genbank/ncbi_dataset/data/data_summary.tsv
#   inflating: y1_final_genbank/ncbi_dataset/data/assembly_data_report.jsonl
#   inflating: y1_final_genbank/ncbi_dataset/fetch.txt
#   inflating: y1_final_genbank/ncbi_dataset/data/dataset_catalog.json

# %% [markdown]
# **Actually rehydrate the data**<br>
# *Takes a few hours*

# %%
# %%capture
! /home/jupyter-user/notebooks/HPRC_Reassembly/edit/datasets \
    rehydrate \
    --directory y1_final_genbank

# %%
alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018504625.1/GCA_018504625.1_NA20129.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018505825.1/GCA_018505825.1_HG02109.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018504665.1/GCA_018504665.1_NA21309.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018469925.1/GCA_018469925.1_HG02622.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018469415.1/GCA_018469415.1_HG03516.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018466835.1/GCA_018466835.1_HG02257.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018471545.1/GCA_018471545.1_HG01952.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018472575.1/GCA_018472575.1_HG00621.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018469685.1/GCA_018469685.1_HG01361.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018852615.1/GCA_018852615.1_HG002.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018470455.1/GCA_018470455.1_HG02886.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018466985.1/GCA_018466985.1_HG02559.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018472865.1/GCA_018472865.1_HG01978.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018471535.1/GCA_018471535.1_HG02148.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018470465.1/GCA_018470465.1_HG02886.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018471105.1/GCA_018471105.1_HG00741.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018506955.1/GCA_018506955.1_HG00733.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018506125.1/GCA_018506125.1_HG02055.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018505845.1/GCA_018505845.1_HG03492.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018472695.1/GCA_018472695.1_HG01928.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018503265.1/GCA_018503265.1_NA19240.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018472765.1/GCA_018472765.1_HG00735.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018505855.1/GCA_018505855.1_HG02055.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018505865.1/GCA_018505865.1_HG02109.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018504065.1/GCA_018504065.1_HG02723.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018472705.1/GCA_018472705.1_HG01928.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018471065.1/GCA_018471065.1_HG01175.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018469405.1/GCA_018469405.1_HG01258.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018466845.1/GCA_018466845.1_HG02257.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018467155.1/GCA_018467155.1_HG01891.pri.mat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018472585.1/GCA_018472585.1_HG00673.alt.pat.f1_v2_genomic.fna',
#  './y1_final_genbank/ncbi_dataset/data/GCA_018472845.1/GCA_018472845.1_HG01978.alt.pat.f1_v2_genomic.fna']

# %% [markdown]
# **Create Data Frame, and Pull The Sample Name And Haplotype From Original File Name**

# %%
assembly_df = pd.DataFrame(original_file_ls, columns=['original_fasta_loc'])

# %%
file_name = assembly_df['original_fasta_loc'].str.split("/", expand=True)[5]

# %%
sample_haplotype = file_name.str.split("_", expand=True)[2]

# %%
assembly_df['sample'] = sample_haplotype.str.split(".", expand=True)[0]

# %%
assembly_df['haplotype'] = sample_haplotype.str.split(".", expand=True)[2]

# %%
assembly_df['mat_pat_int'] =  np.where(assembly_df['haplotype'] == "pat", 1, 2)

# %%
print(assembly_df)
# Out:
#                                    original_fasta_loc   sample haplotype  \
# 0   ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01123       pat
# 1   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  NA19240       mat
# 2   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG01109       mat
# 3   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG03098       pat
# 4   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG02572       mat
# ..                                                ...      ...       ...
# 89  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01258       mat
# 90  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG02257       mat
# 91  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01891       mat
# 92  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG00673       pat
# 93  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG01978       pat
#
#     mat_pat_int
# 0             1
# 1             2
# 2             2
# 3             1
# 4             2
# ..          ...
# 89            2
# 90            2
# 91            2
# 92            1
# 93            1
#
# [94 rows x 4 columns]

# %% [markdown]
# # Copy Assemblies To Bucket

# %%
gcp_raw_assemblies_fp = f"{bucket}genbank_assemblies/raw"

# %%
! gsutil -m cp -r y1_final_genbank/ncbi_dataset/data/ {gcp_raw_assemblies_fp}
# Out:
# Copying file://y1_final_genbank/ncbi_dataset/data/assembly_data_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/dataset_catalog.json [Content-Type=application/json]...
# Copying file://y1_final_genbank/ncbi_dataset/data/data_summary.tsv [Content-Type=text/tab-separated-values]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018
1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472835.1/GCA_018472835.1_HG03579.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472835.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466855.1/GCA_018466855.1_HG02559.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466855.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505835.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505835.1/GCA_018505835.1_HG03492.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018504625.1/GCA_018504625.1_NA20129.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018504625.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505825.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505825.1/GCA_018505825.1_HG02109.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018504665.1/GCA_018504665.1_NA21309.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018504665.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469925.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469925.1/GCA_018469925.1_HG02622.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469415.1/GCA_018469415.1_HG03516.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469415.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466835.1/GCA_018466835.1_HG02257.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466835.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471545.1/GCA_018471545.1_HG01952.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471545.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472575.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472575.1/GCA_018472575.1_HG00621.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469685.1/GCA_018469685.1_HG01361.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469685.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018852615.1/GCA_018852615.1_HG002.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018852615.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018470455.1/GCA_018470455.1_HG02886.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018470455.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466985.1/GCA_018466985.1_HG02559.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466985.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472865.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472865.1/GCA_018472865.1_HG01978.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471535.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471535.1/GCA_018471535.1_HG02148.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018470465.1/GCA_018470465.1_HG02886.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018470465.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471105.1/GCA_018471105.1_HG00741.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471105.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018506955.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018506955.1/GCA_018506955.1_HG00733.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018506125.1/GCA_018506125.1_HG02055.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018506125.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505845.1/GCA_018505845.1_HG03492.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505845.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472695.1/GCA_018472695.1_HG01928.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472695.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018503265.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018503265.1/GCA_018503265.1_NA19240.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472765.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472765.1/GCA_018472765.1_HG00735.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505855.1/GCA_018505855.1_HG02055.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505855.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505865.1/GCA_018505865.1_HG02109.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018505865.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018504065.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018504065.1/GCA_018504065.1_HG02723.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472705.1/GCA_018472705.1_HG01928.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472705.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471065.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018471065.1/GCA_018471065.1_HG01175.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469405.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018469405.1/GCA_018469405.1_HG01258.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466845.1/GCA_018466845.1_HG02257.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018466845.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018467155.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018467155.1/GCA_018467155.1_HG01891.pri.mat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472585.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472585.1/GCA_018472585.1_HG00673.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472845.1/sequence_report.jsonl [Content-Type=application/octet-stream]...
# Copying file://y1_final_genbank/ncbi_dataset/data/GCA_018472845.1/GCA_018472845.1_HG01978.alt.pat.f1_v2_genomic.fna [Content-Type=application/octet-stream]...
# | [191/191 files][267.3 GiB/267.3 GiB] 100% Done  41.3 MiB/s ETA 00:00:00
# Operation completed over 191 objects/267.3 GiB.

# %% [markdown]
# **Set location in GCP**

# %%
assembly_df['original_fasta_gcp_loc'] = assembly_df['original_fasta_loc'].str.replace('./y1_final_genbank/ncbi_dataset/data/', 
                                                   'gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/genbank_assemblies/raw/',
                                                    regex=False)

# %% [markdown]
# # Upload To Data Table

# %% [markdown]
# **Have data frame in long format, create mat/pat dataframes then merge**

# %%
mat_df = assembly_df[assembly_df['mat_pat_int'] == 2]
pat_df = assembly_df[assembly_df['mat_pat_int'] == 1]

# %%
upload_df = mat_df.merge(pat_df, left_on='sample', right_on='sample', suffixes=('_mat', '_pat'))

# %%
upload_df
# Out:
#                                original_fasta_loc_mat   sample haplotype_mat  \
# 0   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  NA19240           mat
# 1   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG01109           mat
# 2   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG02572           mat
# 3   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG03540           mat
# 4   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG00733           mat
# 5   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG03579           mat
# 6   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...    HG005           mat
# 7   ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG03516           mat
# 8   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG00621           mat
# 9   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG01175           mat
# 10  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG02486           mat
# 11  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG01071           mat
# 12  ./y1_final_genbank/ncbi_dataset/data/GCA_01885...  HG02145           mat
# 13  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  NA20129           mat
# 14  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG03486           mat
# 15  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  NA18906           mat
# 16  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG02622           mat
# 17  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG00741           mat
# 18  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG00673           mat
# 19  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG03098           mat
# 20  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG02630           mat
# 21  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  NA21309           mat
# 22  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG02080           mat
# 23  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01358           mat
# 24  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG02717           mat
# 25  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG01106           mat
# 26  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01123           mat
# 27  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG03453           mat
# 28  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG00438           mat
# 29  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG02818           mat
# 30  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG01243           mat
# 31  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG02109           mat
# 32  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG01952           mat
# 33  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01361           mat
# 34  ./y1_final_genbank/ncbi_dataset/data/GCA_01885...    HG002           mat
# 35  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG02886           mat
# 36  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG02559           mat
# 37  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG01978           mat
# 38  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG02148           mat
# 39  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG02055           mat
# 40  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG03492           mat
# 41  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG01928           mat
# 42  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...  HG00735           mat
# 43  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...  HG02723           mat
# 44  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01258           mat
# 45  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG02257           mat
# 46  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...  HG01891           mat
#
#     mat_pat_int_mat                         original_fasta_gcp_loc_mat  \
# 0                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 1                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 2                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 3                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 4                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 5                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 6                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 7                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 8                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 9                 2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 10                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 11                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 12                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 13                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 14                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 15                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 16                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 17                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 18                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 19                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 20                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 21                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 22                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 23                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 24                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 25                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 26                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 27                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 28                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 29                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 30                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 31                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 32                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 33                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 34                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 35                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 36                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 37                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 38                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 39                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 40                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 41                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 42                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 43                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 44                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 45                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 46                2  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
#
#                                original_fasta_loc_pat haplotype_pat  \
# 0   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 1   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 2   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 3   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 4   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 5   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 6   ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 7   ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 8   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 9   ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 10  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 11  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 12  ./y1_final_genbank/ncbi_dataset/data/GCA_01885...           pat
# 13  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 14  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 15  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 16  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 17  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 18  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 19  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 20  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 21  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 22  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 23  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 24  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 25  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 26  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 27  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 28  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 29  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 30  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 31  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 32  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 33  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 34  ./y1_final_genbank/ncbi_dataset/data/GCA_01885...           pat
# 35  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 36  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 37  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 38  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 39  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 40  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 41  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 42  ./y1_final_genbank/ncbi_dataset/data/GCA_01847...           pat
# 43  ./y1_final_genbank/ncbi_dataset/data/GCA_01850...           pat
# 44  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 45  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
# 46  ./y1_final_genbank/ncbi_dataset/data/GCA_01846...           pat
#
#     mat_pat_int_pat                         original_fasta_gcp_loc_pat
# 0                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 1                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 2                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 3                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 4                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 5                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 6                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 7                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 8                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 9                 1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 10                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 11                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 12                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 13                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 14                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 15                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 16                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 17                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 18                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 19                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 20                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 21                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 22                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 23                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 24                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 25                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 26                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 27                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 28                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 29                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 30                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 31                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 32                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 33                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 34                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 35                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 36                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 37                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 38                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 39                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 40                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 41                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 42                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 43                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 44                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 45                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...
# 46                1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/g...

# %% [markdown]
# **Get rid of unnecessary columns**

# %%
upload_df = upload_df.drop(['original_fasta_loc_mat', 'original_fasta_loc_pat', 
                            'haplotype_mat', 'haplotype_pat',
                            'mat_pat_int_mat', 'mat_pat_int_pat'], 1)

# %% [markdown]
# **Upload To Data Table**

# %%
upload_df = upload_df.set_index('sample')

# %%
tp.dataframe_to_table("raw_genbank_sample", upload_df)
