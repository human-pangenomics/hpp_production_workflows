# %% [markdown]
# # Notebook 2: Find Contigs To Drop From Assemblies<a class="tocSkip">
#
# **In this notebook we are dropping contaminated contigs + mito contigs from our assemblies. Corrected mito contigs will be added back to the assemblies in a later step.**
#
# **We also pulled the regions that have (non Mito) contamination and write them as a bed file. This is to make sure that we aren't removing entire contigs when only a small portion is contamiation. This checking is done locally since the results are inconsistent and large regions which clearly are contamination often arent flagged.**
#
#
# **The steps that we will take are:**
# 1. Import Statements & Global Variable Definitions
# 2. Load Data Table
# 3. Identify Mito & Contaminated Contigs Then Write To File
# 4. Write Regions With Contamination
# 6. Create Clean_Sample Data Table

# %% [markdown]
# # Import Statements & Global Variable Definitions

# %% [markdown]
# ## Load Python packages
# ----

# %%
# %%capture 
import terra_notebook_utils as tnu
import terra_pandas as tp
import os
import io
import gzip
import pandas as pd
import numpy as np
from Bio import SeqIO
from Bio.Seq import Seq, Alphabet

# %% [markdown]
# ## Set Environment Variables

# %%
# Get the Google billing project name and workspace name
PROJECT = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE = os.path.basename(os.path.dirname(os.getcwd()))
bucket = os.environ['WORKSPACE_BUCKET'] + "/"

# Verify that we've captured the environment variables
print("Billing project: " + PROJECT)
print("Workspace: " + WORKSPACE)
print("Workspace storage bucket: " + bucket)
# Out:
# Billing project: human-pangenome-ucsc
# Workspace: HPRC_Reassembly
# Workspace storage bucket: gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/

# %% [markdown]
# ## Function Definitions

# %%
def write_contam_contigs(contam_fp: str, contam_contigs_fp: str) -> bool:
    
    header_strings = ["========== COMMON CONTAMINANTS IN EUKARYOTES ==========",
                      "========== MITOCHONDRIAL SEQUENCE ==========",
                      "========== REFSEQ: bacteria ==========",
                      "========== REFSEQ: other_eukaryota ==========",
                      "========== PLASTID SEQUENCE ==========",
                      "========== REFSEQ: viruses_and_viroids ==========",
                      "========== REFSEQ: viridiplantae ==========",
                      "========== REFSEQ: chordata ==========",
                      "========== REFSEQ: other_metazoa ==========",
                      "========== REFSEQ: fungi =========="]
    end_string    = ""

    ## Loop through file, and pull adaptor screen entries. (These are written
    ## in between the header_string and the end_string -- if there are any.)
    contam_contigs_ls = []
    
    with open(contam_fp) as infile, open(contam_contigs_fp, 'w') as outfile:
        copy = False
        found_hits = False
        
        for line in infile:
            if line.strip() in header_strings:
                copy = True
                continue
            elif line.strip().startswith('#'):
                continue
            elif line.strip() == end_string:
                copy = False
                continue
            elif copy:
                ## Pull the contig name
                contig_name = line.strip().split()[0] + "\n"
                
                ## Only add if we haven't already
                if contig_name not in contam_contigs_ls: 
                    contam_contigs_ls.append(contig_name)
                    outfile.write(contig_name)
                    found_hits = True
    
    return found_hits

# %%
def write_mito_contigs(contam_fp: str, mito_contigs_fp: str) -> bool:
    
    header_string = "========== MITOCHONDRIAL SEQUENCE =========="
    end_string    = ""

    ## Loop through file, and pull adaptor screen entries. (These are written
    ## in between the header_string and the end_string -- if there are any.)
    contam_contigs_ls = []
    
    with open(contam_fp) as infile, open(mito_contigs_fp, 'w') as outfile:
        copy = False
        found_hits = False
        
        for line in infile:
            if line.strip() == header_string:
                copy = True
                continue
            elif line.strip().startswith('#'):
                continue
            elif "MT" in line.strip():
                continue
            elif line.strip() == end_string:
                copy = False
                continue
            elif copy:
                ## Pull the contig name
                contig_name = line.strip().split()[0] + "\n"
                
                outfile.write(contig_name)
                found_hits = True
    
    return found_hits

# %%
def found_contam_contigs(contam_fp: str) -> bool:
    
    header_strings = ["========== COMMON CONTAMINANTS IN EUKARYOTES ==========",
                      "========== REFSEQ: bacteria ==========",
                      "========== REFSEQ: other_eukaryota ==========",
                      "========== PLASTID SEQUENCE ==========",
                      "========== REFSEQ: viruses_and_viroids ==========",
                      "========== REFSEQ: viridiplantae ==========",
                      "========== REFSEQ: chordata ==========",
                      "========== REFSEQ: other_metazoa ==========",
                      "========== REFSEQ: fungi =========="]
    
    with open(contam_fp) as infile:
        
        found_hits = False
        
        for line in infile:
            if line.strip() in header_strings:
                found_hits = True
    
    return found_hits

# %%
def write_contam_bed(contam_fp: str, output_bed_fn: str) -> bool:
    
    header_strings = ["========== COMMON CONTAMINANTS IN EUKARYOTES ==========",
                      "========== REFSEQ: bacteria ==========",
                      "========== REFSEQ: other_eukaryota ==========",
                      "========== PLASTID SEQUENCE ==========",
                      "========== REFSEQ: viruses_and_viroids ==========",
                      "========== REFSEQ: viridiplantae ==========",
                      "========== REFSEQ: chordata ==========",
                      "========== REFSEQ: other_metazoa ==========",
                      "========== REFSEQ: fungi =========="]
    end_string    = ""

    ## Loop through file, and pull adaptor screen entries. (These are written
    ## in between the header_string and the end_string -- if there are any.)
    contam_contigs_ls = []
    
    with open(contam_fp) as infile, open(output_bed_fn, 'w') as outfile:
        copy = False
        found_hits = False
        
        for line in infile:
            if line.strip() in header_strings:
                copy = True
                continue
            elif line.strip().startswith('#'):
                continue
            elif line.strip() == end_string:
                copy = False
                continue
            elif copy:
                ## Pull the contig name
                split_line = line.strip().split()

                contig = split_line[0]
                start  = str(int(split_line[6]) - 1)
                stop   = str(split_line[7])
                bed_line = contig + "\t" + start + "\t" + stop + "\n"
            
                outfile.write(bed_line)
                found_hits = True
    
    return found_hits

# %% [markdown]
# # Load Data Table

# %%
decont_results_df = tp.table_to_dataframe("mask_adapter_sample")

decont_results_df.head()
# Out:
#                                                           mat_adapter_bed  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
#
#                                                             mat_masked_fa  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
#
#                                                           pat_adapter_bed  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
#
#                                                        pat_contam_results  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
#
#                                                           pat_adapter_paf  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
#
#                                                            hifiasm_mat_fa  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                            hifiasm_pat_fa  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                           mat_adapter_paf  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
#
#                        sample_name  \
# mask_adapter_sample_id
# HG002_downsampled            HG002
# HG002_full_v0.14             HG002
# HG00438                    HG00438
# HG005                        HG005
# HG00621                    HG00621
#
#                                                             pat_masked_fa  \
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
#
#                                                        mat_contam_results
# mask_adapter_sample_id
# HG002_downsampled       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG002_full_v0.14        gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00438                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG005                   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00621                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...

# %% [markdown]
# # Identify Mito & Contaminated Contigs Then Write To Files
#
# **We will write a file of mito + contamin. contigs that we will use to drop from our assemblies.**
#
# **We also write a file of just mito contigs that will be used for semimanual correction.**

# %%
! mkdir drop_contigs
# %cd drop_contigs
# Out:
# mkdir: cannot create directory ‘drop_contigs’: File exists
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit/drop_contigs

# %%
contam_haplotypes = []

for index, row in decont_results_df.iterrows():
    
    sample_id = row.name
    
    ## Get path to decontamination results
    mat_decont_results_fp = row['mat_contam_results']
    pat_decont_results_fp = row['pat_contam_results']
    
    ## Extract file names
    mat_decont_results_fn = os.path.basename(mat_decont_results_fp)
    pat_decont_results_fn = os.path.basename(pat_decont_results_fp)
    
    ## Copy files to VM
    ! gsutil cp {mat_decont_results_fp} .
    ! gsutil cp {pat_decont_results_fp} .
    
    
    ## WRITE CONTAMINATED CONTIGS (AS LIST) TO FILE
    
    ## output file names
    mat_drop_list_fn = sample_id + ".mat_drop_contigs.txt"
    pat_drop_list_fn = sample_id + ".pat_drop_contigs.txt"    
    
    ## Extract results and write files
    write_contam_contigs(mat_decont_results_fn, mat_drop_list_fn)
    write_contam_contigs(pat_decont_results_fn, pat_drop_list_fn)
    
    ## upload to bucket
    ! gsutil cp {mat_drop_list_fn} {bucket}contigs_to_drop/{mat_drop_list_fn}
    ! gsutil cp {pat_drop_list_fn} {bucket}contigs_to_drop/{pat_drop_list_fn}  
    
    
    ## WRITE MITO CONTIGS (AS LIST) TO FILE
    
    ## output file names
    mat_mito_list_fn = sample_id + ".mat_mito_contigs.txt"
    pat_mito_list_fn = sample_id + ".pat_mito_contigs.txt"    
    
    ## Extract results and write files
    write_mito_contigs(mat_decont_results_fn, mat_mito_list_fn)
    write_mito_contigs(pat_decont_results_fn, pat_mito_list_fn)
    
    ## upload to bucket
    ! gsutil cp {mat_mito_list_fn} {bucket}mito_work/contig_list/{mat_mito_list_fn}
    ! gsutil cp {pat_mito_list_fn} {bucket}mito_work/contig_list/{pat_mito_list_fn}
    
    
    ## ADD TO LIST OF CONTAMINATED CONTIGS (TO CHECK BY EYE)
    if (found_contam_contigs(mat_decont_results_fn)):
        hap_name = sample_id + "-mat"
        contam_haplotypes.append(hap_name)
        
    if (found_contam_contigs(pat_decont_results_fn)):
        hap_name = sample_id + "-pat"
        contam_haplotypes.append(hap_name)
# Out:
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002_downsampled.mat.contamination.short...
# / [1 files][  864.0 B/  864.0 B]
# Operation completed over 1 objects/864.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002_downsampled.pat.contamination.short...
# / [1 files][499.0 KiB/499.0 KiB]
# Operation completed over 1 objects/499.0 KiB.
# Copying file://HG002_downsampled.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  240.0 B/  240.0 B]
# Operation completed over 1 objects/240.0 B.
# Copying file://HG002_downsampled.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   60.0 B/   60.0 B]
# Operation completed over 1 objects/60.0 B.
# Copying file://HG002_downsampled.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  240.0 B/  240.0 B]
# Operation completed over 1 objects/240.0 B.
# Copying file://HG002_downsampled.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002-full-0.14.mat.contamination.short...
# / [1 files][364.3 KiB/364.3 KiB]
# Operation completed over 1 objects/364.3 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002-full-0.14.pat.contamination.short...
# / [1 files][  3.9 MiB/  3.9 MiB]
# Operation completed over 1 objects/3.9 MiB.
# Copying file://HG002_full_v0.14.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  708.0 B/  708.0 B]
# Operation completed over 1 objects/708.0 B.
# Copying file://HG002_full_v0.14.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  1.2 KiB/  1.2 KiB]
# Operation completed over 1 objects/1.2 KiB.
# Copying file://HG002_full_v0.14.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  696.0 B/  696.0 B]
# Operation completed over 1 objects/696.0 B.
# Copying file://HG002_full_v0.14.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  936.0 B/  936.0 B]
# Operation completed over 1 objects/936.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00438.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00438.pat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying file://HG00438.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00438.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00438.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00438.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG005.mat.contamination.short...
# / [1 files][  6.2 KiB/  6.2 KiB]
# Operation completed over 1 objects/6.2 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG005.pat.contamination.short...
# / [1 files][  453.0 B/  453.0 B]
# Operation completed over 1 objects/453.0 B.
# Copying file://HG005.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  2.1 KiB/  2.1 KiB]
# Operation completed over 1 objects/2.1 KiB.
# Copying file://HG005.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying file://HG005.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  2.1 KiB/  2.1 KiB]
# Operation completed over 1 objects/2.1 KiB.
# Copying file://HG005.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00621.mat.contamination.short...
# / [1 files][  496.0 B/  496.0 B]
# Operation completed over 1 objects/496.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00621.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00621.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  144.0 B/  144.0 B]
# Operation completed over 1 objects/144.0 B.
# Copying file://HG00621.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00621.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  144.0 B/  144.0 B]
# Operation completed over 1 objects/144.0 B.
# Copying file://HG00621.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00673.mat.contamination.short...
# / [1 files][  495.0 B/  495.0 B]
# Operation completed over 1 objects/495.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00673.pat.contamination.short...
# / [1 files][  271.0 B/  271.0 B]
# Operation completed over 1 objects/271.0 B.
# Copying file://HG00673.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  144.0 B/  144.0 B]
# Operation completed over 1 objects/144.0 B.
# Copying file://HG00673.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00673.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  144.0 B/  144.0 B]
# Operation completed over 1 objects/144.0 B.
# Copying file://HG00673.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00733.mat.contamination.short...
# / [1 files][111.6 KiB/111.6 KiB]
# Operation completed over 1 objects/111.6 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00733.pat.contamination.short...
# / [1 files][111.6 KiB/111.6 KiB]
# Operation completed over 1 objects/111.6 KiB.
# Copying file://HG00733.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  156.0 B/  156.0 B]
# Operation completed over 1 objects/156.0 B.
# Copying file://HG00733.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   36.0 B/   36.0 B]
# Operation completed over 1 objects/36.0 B.
# Copying file://HG00733.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  144.0 B/  144.0 B]
# Operation completed over 1 objects/144.0 B.
# Copying file://HG00733.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00735.mat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00735.pat.contamination.short...
# / [1 files][   97.0 B/   97.0 B]
# Operation completed over 1 objects/97.0 B.
# Copying file://HG00735.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00735.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00735.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00735.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00741.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00741.pat.contamination.short...
# / [1 files][   93.0 B/   93.0 B]
# Operation completed over 1 objects/93.0 B.
# Copying file://HG00741.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00741.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00741.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG00741.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01071.mat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01071.pat.contamination.short...
# / [1 files][   92.0 B/   92.0 B]
# Operation completed over 1 objects/92.0 B.
# Copying file://HG01071.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01071.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01071.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01071.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01106.mat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01106.pat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying file://HG01106.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01106.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01106.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01106.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01109.mat.contamination.short...
# / [1 files][  257.0 B/  257.0 B]
# Operation completed over 1 objects/257.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01109.pat.contamination.short...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying file://HG01109.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying file://HG01109.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01109.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying file://HG01109.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01123.mat.contamination.short...
# / [1 files][  999.0 B/  999.0 B]
# Operation completed over 1 objects/999.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01123.pat.contamination.short...
# / [1 files][  220.0 B/  220.0 B]
# Operation completed over 1 objects/220.0 B.
# Copying file://HG01123.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  288.0 B/  288.0 B]
# Operation completed over 1 objects/288.0 B.
# Copying file://HG01123.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01123.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  288.0 B/  288.0 B]
# Operation completed over 1 objects/288.0 B.
# Copying file://HG01123.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01175.mat.contamination.short...
# / [1 files][  317.0 B/  317.0 B]
# Operation completed over 1 objects/317.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01175.pat.contamination.short...
# / [1 files][  126.0 B/  126.0 B]
# Operation completed over 1 objects/126.0 B.
# Copying file://HG01175.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01175.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01175.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01175.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01243.mat.contamination.short...
# / [1 files][  598.0 B/  598.0 B]
# Operation completed over 1 objects/598.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01243.pat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying file://HG01243.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  180.0 B/  180.0 B]
# Operation completed over 1 objects/180.0 B.
# Copying file://HG01243.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01243.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  180.0 B/  180.0 B]
# Operation completed over 1 objects/180.0 B.
# Copying file://HG01243.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01258.mat.contamination.short...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01258.pat.contamination.short...
# / [1 files][  222.0 B/  222.0 B]
# Operation completed over 1 objects/222.0 B.
# Copying file://HG01258.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  300.0 B/  300.0 B]
# Operation completed over 1 objects/300.0 B.
# Copying file://HG01258.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01258.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  300.0 B/  300.0 B]
# Operation completed over 1 objects/300.0 B.
# Copying file://HG01258.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01358.mat.contamination.short...
# / [1 files][  1.3 KiB/  1.3 KiB]
# Operation completed over 1 objects/1.3 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01358.pat.contamination.short...
# / [1 files][   97.0 B/   97.0 B]
# Operation completed over 1 objects/97.0 B.
# Copying file://HG01358.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  408.0 B/  408.0 B]
# Operation completed over 1 objects/408.0 B.
# Copying file://HG01358.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01358.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  408.0 B/  408.0 B]
# Operation completed over 1 objects/408.0 B.
# Copying file://HG01358.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01361.mat.contamination.short...
# / [1 files][  631.0 B/  631.0 B]
# Operation completed over 1 objects/631.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01361.pat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying file://HG01361.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  192.0 B/  192.0 B]
# Operation completed over 1 objects/192.0 B.
# Copying file://HG01361.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01361.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  192.0 B/  192.0 B]
# Operation completed over 1 objects/192.0 B.
# Copying file://HG01361.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01891.mat.contamination.short...
# / [1 files][  697.0 B/  697.0 B]
# Operation completed over 1 objects/697.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01891.pat.contamination.short...
# / [1 files][   96.0 B/   96.0 B]
# Operation completed over 1 objects/96.0 B.
# Copying file://HG01891.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  180.0 B/  180.0 B]
# Operation completed over 1 objects/180.0 B.
# Copying file://HG01891.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01891.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  180.0 B/  180.0 B]
# Operation completed over 1 objects/180.0 B.
# Copying file://HG01891.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01928.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01928.pat.contamination.short...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying file://HG01928.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01928.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01928.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01928.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01952.mat.contamination.short...
# / [1 files][  193.0 B/  193.0 B]
# Operation completed over 1 objects/193.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01952.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01952.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   36.0 B/   36.0 B]
# Operation completed over 1 objects/36.0 B.
# Copying file://HG01952.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01952.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   36.0 B/   36.0 B]
# Operation completed over 1 objects/36.0 B.
# Copying file://HG01952.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01978.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01978.pat.contamination.short...
# / [1 files][   95.0 B/   95.0 B]
# Operation completed over 1 objects/95.0 B.
# Copying file://HG01978.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01978.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01978.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG01978.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02055.mat.contamination.short...
# / [1 files][  999.0 B/  999.0 B]
# Operation completed over 1 objects/999.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02055.pat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying file://HG02055.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  288.0 B/  288.0 B]
# Operation completed over 1 objects/288.0 B.
# Copying file://HG02055.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG02055.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  288.0 B/  288.0 B]
# Operation completed over 1 objects/288.0 B.
# Copying file://HG02055.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02080.mat.contamination.short...
# / [1 files][  392.0 B/  392.0 B]
# Operation completed over 1 objects/392.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02080.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02080_split.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   72.0 B/   72.0 B]
# Operation completed over 1 objects/72.0 B.
# Copying file://HG02080_split.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02080_split.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   72.0 B/   72.0 B]
# Operation completed over 1 objects/72.0 B.
# Copying file://HG02080_split.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02109.mat.contamination.short...
# / [1 files][  195.0 B/  195.0 B]
# Operation completed over 1 objects/195.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02109.pat.contamination.short...
# / [1 files][  138.0 B/  138.0 B]
# Operation completed over 1 objects/138.0 B.
# Copying file://HG02109.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   36.0 B/   36.0 B]
# Operation completed over 1 objects/36.0 B.
# Copying file://HG02109.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02109.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   36.0 B/   36.0 B]
# Operation completed over 1 objects/36.0 B.
# Copying file://HG02109.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02145.mat.contamination.short...
# / [1 files][  357.0 B/  357.0 B]
# Operation completed over 1 objects/357.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02145.pat.contamination.short...
# / [1 files][  257.0 B/  257.0 B]
# Operation completed over 1 objects/257.0 B.
# Copying file://HG02145.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   60.0 B/   60.0 B]
# Operation completed over 1 objects/60.0 B.
# Copying file://HG02145.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying file://HG02145.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   60.0 B/   60.0 B]
# Operation completed over 1 objects/60.0 B.
# Copying file://HG02145.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02148.mat.contamination.short...
# / [1 files][  737.0 B/  737.0 B]
# Operation completed over 1 objects/737.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02148.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02148.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  228.0 B/  228.0 B]
# Operation completed over 1 objects/228.0 B.
# Copying file://HG02148.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02148.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  228.0 B/  228.0 B]
# Operation completed over 1 objects/228.0 B.
# Copying file://HG02148.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02257.mat.contamination.short...
# / [1 files][  626.0 B/  626.0 B]
# Operation completed over 1 objects/626.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02257.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02257.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  156.0 B/  156.0 B]
# Operation completed over 1 objects/156.0 B.
# Copying file://HG02257.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02257.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  156.0 B/  156.0 B]
# Operation completed over 1 objects/156.0 B.
# Copying file://HG02257.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02486.mat.contamination.short...
# / [1 files][   1005 B/   1005 B]
# Operation completed over 1 objects/1005.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02486.pat.contamination.short...
# / [1 files][   93.0 B/   93.0 B]
# Operation completed over 1 objects/93.0 B.
# Copying file://HG02486.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  288.0 B/  288.0 B]
# Operation completed over 1 objects/288.0 B.
# Copying file://HG02486.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02486.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  288.0 B/  288.0 B]
# Operation completed over 1 objects/288.0 B.
# Copying file://HG02486.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02559.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02559.pat.contamination.short...
# / [1 files][  224.0 B/  224.0 B]
# Operation completed over 1 objects/224.0 B.
# Copying file://HG02559.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG02559.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG02559.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG02559.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02572.mat.contamination.short...
# / [1 files][  903.0 B/  903.0 B]
# Operation completed over 1 objects/903.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02572.pat.contamination.short...
# / [1 files][  222.0 B/  222.0 B]
# Operation completed over 1 objects/222.0 B.
# Copying file://HG02572.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  252.0 B/  252.0 B]
# Operation completed over 1 objects/252.0 B.
# Copying file://HG02572.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG02572.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  252.0 B/  252.0 B]
# Operation completed over 1 objects/252.0 B.
# Copying file://HG02572.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02622.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02622.pat.contamination.short...
# / [1 files][   96.0 B/   96.0 B]
# Operation completed over 1 objects/96.0 B.
# Copying file://HG02622.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG02622.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02622.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG02622.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# ...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying file://HG03098.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG03098.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG03098.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG03098.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03453.mat.contamination.short...
# / [1 files][  765.0 B/  765.0 B]
# Operation completed over 1 objects/765.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03453.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03453.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  204.0 B/  204.0 B]
# Operation completed over 1 objects/204.0 B.
# Copying file://HG03453.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03453.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  204.0 B/  204.0 B]
# Operation completed over 1 objects/204.0 B.
# Copying file://HG03453.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03486.mat.contamination.short...
# / [1 files][  946.0 B/  946.0 B]
# Operation completed over 1 objects/946.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03486.pat.contamination.short...
# / [1 files][  304.0 B/  304.0 B]
# Operation completed over 1 objects/304.0 B.
# Copying file://HG03486.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  252.0 B/  252.0 B]
# Operation completed over 1 objects/252.0 B.
# Copying file://HG03486.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying file://HG03486.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  252.0 B/  252.0 B]
# Operation completed over 1 objects/252.0 B.
# Copying file://HG03486.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   24.0 B/   24.0 B]
# Operation completed over 1 objects/24.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03492.mat.contamination.short...
# / [1 files][  590.0 B/  590.0 B]
# Operation completed over 1 objects/590.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03492.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03492.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  144.0 B/  144.0 B]
# Operation completed over 1 objects/144.0 B.
# Copying file://HG03492.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03492.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  144.0 B/  144.0 B]
# Operation completed over 1 objects/144.0 B.
# Copying file://HG03492.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03516.mat.contamination.short...
# / [1 files][  531.0 B/  531.0 B]
# Operation completed over 1 objects/531.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03516.pat.contamination.short...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying file://HG03516.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  156.0 B/  156.0 B]
# Operation completed over 1 objects/156.0 B.
# Copying file://HG03516.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://HG03516.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  156.0 B/  156.0 B]
# Operation completed over 1 objects/156.0 B.
# Copying file://HG03516.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03540.mat.contamination.short...
# / [1 files][  729.0 B/  729.0 B]
# Operation completed over 1 objects/729.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03540.pat.contamination.short...
# / [1 files][   97.0 B/   97.0 B]
# Operation completed over 1 objects/97.0 B.
# Copying file://HG03540.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  192.0 B/  192.0 B]
# Operation completed over 1 objects/192.0 B.
# Copying file://HG03540.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03540.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  192.0 B/  192.0 B]
# Operation completed over 1 objects/192.0 B.
# Copying file://HG03540.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03579.mat.contamination.short...
# / [1 files][  692.0 B/  692.0 B]
# Operation completed over 1 objects/692.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03579.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03579.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  180.0 B/  180.0 B]
# Operation completed over 1 objects/180.0 B.
# Copying file://HG03579.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03579.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  180.0 B/  180.0 B]
# Operation completed over 1 objects/180.0 B.
# Copying file://HG03579.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA18906.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA18906.pat.contamination.short...
# / [1 files][  128.0 B/  128.0 B]
# Operation completed over 1 objects/128.0 B.
# Copying file://NA18906.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://NA18906.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://NA18906.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://NA18906.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA19240.mat.contamination.short...
# / [1 files][  1.6 KiB/  1.6 KiB]
# Operation completed over 1 objects/1.6 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA19240.pat.contamination.short...
# / [1 files][  280.0 B/  280.0 B]
# Operation completed over 1 objects/280.0 B.
# Copying file://NA19240.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  528.0 B/  528.0 B]
# Operation completed over 1 objects/528.0 B.
# Copying file://NA19240.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://NA19240.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  528.0 B/  528.0 B]
# Operation completed over 1 objects/528.0 B.
# Copying file://NA19240.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA20129.mat.contamination.short...
# / [1 files][  615.0 B/  615.0 B]
# Operation completed over 1 objects/615.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA20129.pat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying file://NA20129.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  156.0 B/  156.0 B]
# Operation completed over 1 objects/156.0 B.
# Copying file://NA20129.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying file://NA20129.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  156.0 B/  156.0 B]
# Operation completed over 1 objects/156.0 B.
# Copying file://NA20129.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][   12.0 B/   12.0 B]
# Operation completed over 1 objects/12.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA21309.mat.contamination.short...
# / [1 files][  868.0 B/  868.0 B]
# Operation completed over 1 objects/868.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA21309.pat.contamination.short...
# / [1 files][  169.0 B/  169.0 B]
# Operation completed over 1 objects/169.0 B.
# Copying file://NA21309.mat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][  216.0 B/  216.0 B]
# Operation completed over 1 objects/216.0 B.
# Copying file://NA21309.pat_drop_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://NA21309.mat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][  216.0 B/  216.0 B]
# Operation completed over 1 objects/216.0 B.
# Copying file://NA21309.pat_mito_contigs.txt [Content-Type=text/plain]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.

# %%
## Add links to contgis that we will drop (used by dropFastaContigs workflow)
decont_results_df['mat_drop_contigs'] = f"{bucket}contigs_to_drop/" + decont_results_df.index + ".mat_drop_contigs.txt"
decont_results_df['pat_drop_contigs'] = f"{bucket}contigs_to_drop/" + decont_results_df.index + ".pat_drop_contigs.txt"

## Add links to mito contigs that we will use for MT assembly (will map against reference with minimap2 next)
decont_results_df['mat_mito_contig_ls'] = f"{bucket}mito_work/contig_list/" + decont_results_df.index + ".mat_mito_contigs.txt"
decont_results_df['pat_mito_contig_ls'] = f"{bucket}mito_work/contig_list/" + decont_results_df.index + ".pat_mito_contigs.txt"

# %% [markdown]
# # Write Regions With Contamination
#
# **Write bed files of all of the regions that are contaminated in the samples that have contamination. We will use these files to check for whether or not the entirety of the contigs that we are dropping are contamination. If not, then we might be throwing away good sequence.**
#
# *Will do the checking on local machine*

# %% [markdown]
# ## Show Which Assemblies We Need Beds For

# %%
print(contam_haplotypes)
# Out:
# ['HG002_downsampled-pat', 'HG002_full_v0.14-mat', 'HG002_full_v0.14-pat', 'HG00733-mat', 'HG00733-pat']

# %% [markdown]
# ## HG002 Downsampled

# %%
sample_id = 'HG002_downsampled'

is_sample_row = decont_results_df.index == sample_id
row           = decont_results_df.loc[is_sample_row]

pat_decont_results_fp = row['pat_contam_results'][0]
    
pat_decont_results_fn = os.path.basename(pat_decont_results_fp)

pat_bed_fn = f"{sample_id}.pat.contam.bed"

write_contam_bed(pat_decont_results_fn, pat_bed_fn)

! gsutil cp {pat_bed_fn} {bucket}kerstin_decontam_results/bed_files/{pat_bed_fn}
# Out:
# Copying file://HG002_downsampled.pat.contam.bed [Content-Type=application/octet-stream]...
# / [1 files][105.3 KiB/105.3 KiB]
# Operation completed over 1 objects/105.3 KiB.

# %% [markdown]
# ## HG002 Full

# %%
sample_id = 'HG002_full_v0.14'

is_sample_row = decont_results_df.index == sample_id
row           = decont_results_df.loc[is_sample_row]

mat_decont_results_fp = row['mat_contam_results'][0]
pat_decont_results_fp = row['pat_contam_results'][0]
    
mat_decont_results_fn = os.path.basename(mat_decont_results_fp)
pat_decont_results_fn = os.path.basename(pat_decont_results_fp)

mat_bed_fn = f"{sample_id}.mat.contam.bed"
pat_bed_fn = f"{sample_id}.pat.contam.bed"

write_contam_bed(mat_decont_results_fn, mat_bed_fn)
write_contam_bed(pat_decont_results_fn, pat_bed_fn)

! gsutil cp {mat_bed_fn} {bucket}kerstin_decontam_results/bed_files/{mat_bed_fn}
! gsutil cp {pat_bed_fn} {bucket}kerstin_decontam_results/bed_files/{pat_bed_fn}
# Out:
# Copying file://HG002_full_v0.14.mat.contam.bed [Content-Type=application/octet-stream]...
# / [1 files][ 83.6 KiB/ 83.6 KiB]
# Operation completed over 1 objects/83.6 KiB.
# Copying file://HG002_full_v0.14.pat.contam.bed [Content-Type=application/octet-stream]...
# / [1 files][895.2 KiB/895.2 KiB]
# Operation completed over 1 objects/895.2 KiB.

# %% [markdown]
# ## HG00733

# %%
sample_id = 'HG00733'

is_sample_row = decont_results_df.index == sample_id
row           = decont_results_df.loc[is_sample_row]

mat_decont_results_fp = row['mat_contam_results'][0]
pat_decont_results_fp = row['pat_contam_results'][0]
    
mat_decont_results_fn = os.path.basename(mat_decont_results_fp)
pat_decont_results_fn = os.path.basename(pat_decont_results_fp)

mat_bed_fn = f"{sample_id}.mat.contam.bed"
pat_bed_fn = f"{sample_id}.pat.contam.bed"

write_contam_bed(mat_decont_results_fn, mat_bed_fn)
write_contam_bed(pat_decont_results_fn, pat_bed_fn)

! gsutil cp {mat_bed_fn} {bucket}kerstin_decontam_results/bed_files/{mat_bed_fn}
! gsutil cp {pat_bed_fn} {bucket}kerstin_decontam_results/bed_files/{pat_bed_fn}
# Out:
# Copying file://HG00733.mat.contam.bed [Content-Type=application/octet-stream]...
# / [1 files][ 24.0 KiB/ 24.0 KiB]
# Operation completed over 1 objects/24.0 KiB.
# Copying file://HG00733.pat.contam.bed [Content-Type=application/octet-stream]...
# / [1 files][ 24.0 KiB/ 24.0 KiB]
# Operation completed over 1 objects/24.0 KiB.

# %% [markdown]
# # Create Clean_Sample Data Table

# %%
upload_df = decont_results_df.copy()
upload_df = upload_df.rename(index={'1': 'clean_sample_id'})

## Don't need adapter info going forward
upload_df.drop(columns = ["mat_adapter_bed", "mat_adapter_paf", "pat_adapter_bed", "pat_adapter_paf"],
               inplace = True)

# %%
tp.dataframe_to_table("clean_sample", upload_df)
