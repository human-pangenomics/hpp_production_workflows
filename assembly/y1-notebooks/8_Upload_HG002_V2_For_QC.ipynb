# %% [markdown]
# # Notebook 8: Upload HG002 Assemblies For Kerstin<a class="tocSkip">
#
# **Upload more versions of HG002 for Kerstin to run**
#
#
# **The steps that we will take are:**
# 1. Import Statements & Global Variable Definitions
# 2. Read In Data Tables
# 3. Upload Assemblies

# %% [markdown]
# # Import Statements & Global Variable Definitions

# %%
# %%capture
# %pip install --upgrade --no-cache-dir git+https://github.com/DataBiosphere/ssds

# %%
import terra_notebook_utils as tnu
import terra_pandas as tp
import pandas as pd
import os
from ssds import deployment
from pprint import pprint
import gcsfs
import seaborn as sns
# %matplotlib inline
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %% [markdown]
# ## Global Variable Definitions

# %%
## submission_id is generated by uuid (gives unique ID to each submission)
submission_id       = "9464E2BC-3F4C-4226-9813-0E91F9AD612E"

## submission_name lends some recognizability to the submission
submission_name     = "HG002_UPDATED_ASSEMBLIES"

ds = deployment._GSStaging(google_billing_project="firecloud-cgl")   # _GSStaging()
destintation_bucket = "gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf" # _GSStaging()

## Where the submission files will actually land (we may add one directory level later)
dest_full_path      = os.path.join(destintation_bucket, "submissions", submission_id + "--" + submission_name)

# %% [markdown]
# ## Set Environment Variables

# %%
# Get the Google billing project name and workspace name
PROJECT = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE =os.path.basename(os.path.dirname(os.getcwd()))
bucket = os.environ['WORKSPACE_BUCKET'] + "/"

# Verify that we've captured the environment variables
print("Billing project: " + PROJECT)
print("Workspace: " + WORKSPACE)
print("Workspace storage bucket: " + bucket)
# Out:
# Billing project: human-pangenome-ucsc
# Workspace: HPRC_Reassembly
# Workspace storage bucket: gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/

# %% [markdown]
# # Read In Data Tables
#
# ## Read In Original QC Samples

# %%
sample_df = tp.table_to_dataframe("sample")

sample_df.head()
# Out:
#                                                               QCstats  \
# sample_id
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/b...
# HG002_downsampled   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/b...
# HG002_full_v0.14    gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/e...
# HG00438             gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/b...
#
#                                                              mat_ilmn  \
# sample_id
# HG002_chem_v2       gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
# HG002_downsampled   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
# HG002_full_v0.14    [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG002_full_v0.14.1                                                NaN
# HG00438             [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                                  hifi  \
# sample_id
# HG002_chem_v2       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG002_downsampled   [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG002_full_v0.14    [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG002_full_v0.14.1                                                NaN
# HG00438             [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                    paternal_id  \
# sample_id
# HG002_chem_v2            HG003
# HG002_downsampled        HG003
# HG002_full_v0.14         HG003
# HG002_full_v0.14.1       HG003
# HG00438                HG00436
#
#                                                                matYak  \
# sample_id
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_downsampled   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_full_v0.14    gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG00438             gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
#
#                    maternal_id  \
# sample_id
# HG002_chem_v2            HG004
# HG002_downsampled        HG004
# HG002_full_v0.14         HG004
# HG002_full_v0.14.1       HG004
# HG00438                HG00437
#
#                                                                patYak  \
# sample_id
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_downsampled   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_full_v0.14    gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG00438             gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
#
#                                                              nanopore  \
# sample_id
# HG002_chem_v2       gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
# HG002_downsampled   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
# HG002_full_v0.14    [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG002_full_v0.14.1                                                NaN
# HG00438             [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                              pat_ilmn  \
# sample_id
# HG002_chem_v2       gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
# HG002_downsampled   gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
# HG002_full_v0.14    [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG002_full_v0.14.1                                                NaN
# HG00438             [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                       maternalFastaGz  ...  \
# sample_id                                                              ...
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/6...  ...
# HG002_downsampled   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...  ...
# HG002_full_v0.14    gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...  ...
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/H...  ...
# HG00438             gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...  ...
#
#                                                 adapterBlockListTarGz  \
# sample_id
# HG002_chem_v2                                                     NaN
# HG002_downsampled   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14                                                  NaN
# HG002_full_v0.14.1                                                NaN
# HG00438             gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                       countReadsTarGz  \
# sample_id
# HG002_chem_v2                                                     NaN
# HG002_downsampled   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14                                                  NaN
# HG002_full_v0.14.1                                                NaN
# HG00438             gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                         binFilesTarGz  \
# sample_id
# HG002_chem_v2                                                     NaN
# HG002_downsampled   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14                                                  NaN
# HG002_full_v0.14.1                                                NaN
# HG00438             gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                                   hic  \
# sample_id
# HG002_chem_v2                                                     NaN
# HG002_downsampled                                                 NaN
# HG002_full_v0.14                                                   []
# HG002_full_v0.14.1                                                NaN
# HG00438             [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                          bionano_cmap  \
# sample_id
# HG002_chem_v2                                                     NaN
# HG002_downsampled                                                 NaN
# HG002_full_v0.14                                                   []
# HG002_full_v0.14.1                                                NaN
# HG00438             [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                           bionano_bnx  \
# sample_id
# HG002_chem_v2                                                     NaN
# HG002_downsampled                                                 NaN
# HG002_full_v0.14                                                   []
# HG002_full_v0.14.1                                                NaN
# HG00438             [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                    strandseq notes patAssemblyChm13WinnowmapBam  \
# sample_id
# HG002_chem_v2            NaN   NaN                          NaN
# HG002_downsampled        NaN   NaN                          NaN
# HG002_full_v0.14          []   NaN                          NaN
# HG002_full_v0.14.1       NaN   NaN                          NaN
# HG00438                   []   NaN                          NaN
#
#                    matAssemblyChm13WinnowmapBam
# sample_id
# HG002_chem_v2                               NaN
# HG002_downsampled                           NaN
# HG002_full_v0.14                            NaN
# HG002_full_v0.14.1                          NaN
# HG00438                                     NaN
#
# [5 rows x 26 columns]

# %%
samples_to_keep = ["HG002_full_v0.14.1", "HG002_chem_v2"]

HG002_sample_df = sample_df.loc[samples_to_keep]

HG002_sample_df
# Out:
#                                                               QCstats  \
# sample_id
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/e...
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/b...
#
#                                                              mat_ilmn  \
# sample_id
# HG002_full_v0.14.1                                                NaN
# HG002_chem_v2       gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
#
#                                                                  hifi  \
# sample_id
# HG002_full_v0.14.1                                                NaN
# HG002_chem_v2       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                    paternal_id  \
# sample_id
# HG002_full_v0.14.1       HG003
# HG002_chem_v2            HG003
#
#                                                                matYak  \
# sample_id
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
#
#                    maternal_id  \
# sample_id
# HG002_full_v0.14.1       HG004
# HG002_chem_v2            HG004
#
#                                                                patYak  \
# sample_id
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/y...
#
#                                                              nanopore  \
# sample_id
# HG002_full_v0.14.1                                                NaN
# HG002_chem_v2       gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
#
#                                                              pat_ilmn  \
# sample_id
# HG002_full_v0.14.1                                                NaN
# HG002_chem_v2       gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/s...
#
#                                                       maternalFastaGz  ...  \
# sample_id                                                              ...
# HG002_full_v0.14.1  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/H...  ...
# HG002_chem_v2       gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/6...  ...
#
#                    adapterBlockListTarGz countReadsTarGz binFilesTarGz  hic  \
# sample_id
# HG002_full_v0.14.1                   NaN             NaN           NaN  NaN
# HG002_chem_v2                        NaN             NaN           NaN  NaN
#
#                    bionano_cmap bionano_bnx strandseq notes  \
# sample_id
# HG002_full_v0.14.1          NaN         NaN       NaN   NaN
# HG002_chem_v2               NaN         NaN       NaN   NaN
#
#                    patAssemblyChm13WinnowmapBam matAssemblyChm13WinnowmapBam
# sample_id
# HG002_full_v0.14.1                          NaN                          NaN
# HG002_chem_v2                               NaN                          NaN
#
# [2 rows x 26 columns]

# %% [markdown]
# # Upload Assemblies
# ## Upload Directly From GCP w/ SSDS

# %%
## Loop through rows of data table, upload fastas
for index, row in HG002_sample_df.iterrows():
    
    sample_id   = row.name
    
    mat_fa_fp = row['maternalFastaGz']
    pat_fa_fp = row['paternalFastaGz']

    mat_fa_fn = os.path.basename(mat_fa_fp)
    pat_fa_fn = os.path.basename(pat_fa_fp)
        
    mat_subm_path = f"{sample_id}/{mat_fa_fn}"
    pat_subm_path = f"{sample_id}/{pat_fa_fn}"
                
    ds.copy(mat_fa_fp, submission_id, submission_name, mat_subm_path)
    ds.copy(pat_fa_fp, submission_id, submission_name, pat_subm_path)
# Out:
# 2021-03-26 03:15:52::INFO  Copied gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/HG002_FULL_V0.14.1/HG002-full-0.14.1.mat.fa.gz to gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/submissions/9464E2BC-3F4C-4226-9813-0E91F9AD612E--HG002_UPDATED_ASSEMBLIES/HG002_full_v0.14.1/HG002-full-0.14.1.mat.fa.gz
# 2021-03-26 03:16:04::INFO  Copied gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/HG002_FULL_V0.14.1/HG002-full-0.14.1.pat.fa.gz to gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/submissions/9464E2BC-3F4C-4226-9813-0E91F9AD612E--HG002_UPDATED_ASSEMBLIES/HG002_full_v0.14.1/HG002-full-0.14.1.pat.fa.gz
# 2021-03-26 03:16:17::INFO  Copied gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/63b5a366-7aab-48e4-92b5-2c9b86553086/trioHifiasmAssembly/aceda867-2cb3-4ef8-a2d3-818c06f009fd/call-gfa2fasta/HG002_chem_v2.mat.fa.gz to gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/submissions/9464E2BC-3F4C-4226-9813-0E91F9AD612E--HG002_UPDATED_ASSEMBLIES/HG002_chem_v2/HG002_chem_v2.mat.fa.gz
# 2021-03-26 03:16:29::INFO  Copied gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/63b5a366-7aab-48e4-92b5-2c9b86553086/trioHifiasmAssembly/aceda867-2cb3-4ef8-a2d3-818c06f009fd/call-gfa2fasta/HG002_chem_v2.pat.fa.gz to gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/submissions/9464E2BC-3F4C-4226-9813-0E91F9AD612E--HG002_UPDATED_ASSEMBLIES/HG002_chem_v2/HG002_chem_v2.pat.fa.gz
