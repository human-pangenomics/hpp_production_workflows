# %% [markdown]
# # Notebook 1: Find Adapter Contamination<a class="tocSkip">
#
# **Create bed files with adapter hits to mask our HPRC Year 1 reassembled samples.**
#
# **In this notbook we will create bed files to mask adapter sequences using hits from Kerstin Howe's decontamination piepline and minimap2 alignments of the PacBio SMRTbell adapter (dimer) to the assemblies.**
#
#
# **The steps that we will take are:**
# 1. Import Statements & Global Variable Definitions
# 3. Extract VecScreen Results
# 4. Extract Adapter Hits From minimap2 PAFs
# 5. Combine Adapter Hits From VecScreen + minimap2
# 6. Look At How Many Adapter Hits We Are Finding
# 7. Create Masking Data Table

# %% [markdown]
# # Import Statements & Global Variable Definitions

# %% [markdown]
# ## Load Python packages
# ----

# %%
# %%capture 
import terra_notebook_utils as tnu
import terra_pandas as tp
import os
import io
import gzip
import pandas as pd
import numpy as np
from Bio import SeqIO

# %% [markdown]
# ## Set Environment Variables

# %%
# Get the Google billing project name and workspace name
PROJECT = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE =os.path.basename(os.path.dirname(os.getcwd()))
bucket = os.environ['WORKSPACE_BUCKET'] + "/"

# Verify that we've captured the environment variables
print("Billing project: " + PROJECT)
print("Workspace: " + WORKSPACE)
print("Workspace storage bucket: " + bucket)
# Out:
# Billing project: human-pangenome-ucsc
# Workspace: HPRC_Reassembly
# Workspace storage bucket: gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/

# %% [markdown]
# ## Function Definitions

# %%
def write_vecscreen_bed(contam_fp: str, output_bed: str) -> bool:
### Writes bed file of adapter sequences identified from Kerstin Howe's decontamination pipeline.
### If no adapter contamination is found and empty file is written.
### Returns bool of whether or not adapter contamination was found.

    header_string = "========== EUKARYOTE ADAPTOR SCREEN =========="
    end_string    = ""

    ## Loop through file, and pull adaptor screen entries. (These are written
    ## in between the header_string and the end_string -- if there are any.)
    with open(contam_fp) as infile, open(output_bed, 'w') as outfile:
        copy = False
        found_hits = False
        
        for line in infile:
            if line.strip() == header_string:
                copy = True
                continue
            elif line.strip() == end_string:
                copy = False
                continue
            elif copy:
                ## Pull lines with VecScreen_Strong entries
                spl_line = line.strip().split("\t")

                if (spl_line[0] == 'VecScreen_Strong') or (spl_line[0] == 'VecScreen_Moderate'):
                    
                    chrom = spl_line[1]
                    start = str(int(spl_line[2]) - 1)
                    stop  = spl_line[3]
                   
                    out_str = chrom + "\t" + start + "\t" + stop  + "\n"
                    outfile.write(out_str)
                    found_hits = True
                    
    return found_hits

# %%
def gz_size(fname):
### Check for empty gzipped file
    with gzip.open(fname, 'rb') as f:
        return f.seek(0, whence=2)

# %% [markdown]
# # Extract VecScreen Results

# %% [markdown]
# ## Read In Data Table

# %% [markdown]
# **Read in data table that has assemblies that have been corrected for MT problems**

# %%
decont_results_df = tp.table_to_dataframe("initial_qc_sample")

decont_results_df.head()
# Out:
#                                                      pat_contam_results  \
# initial_qc_sample_id
# HG002_downsampled     gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG002_full_v0.14      gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00438               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG005                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00621               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
#
#                                                         pat_adapter_paf  \
# initial_qc_sample_id
# HG002_downsampled     gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG002_full_v0.14      gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG00438               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG005                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
# HG00621               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9...
#
#                                                          hifiasm_mat_fa  \
# initial_qc_sample_id
# HG002_downsampled     gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14      gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...
# HG00438               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                          hifiasm_pat_fa  \
# initial_qc_sample_id
# HG002_downsampled     gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14      gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...
# HG00438               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                         mat_adapter_paf  \
# initial_qc_sample_id
# HG002_downsampled     gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG002_full_v0.14      gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG00438               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG005                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG00621               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
#
#                      sample_name  \
# initial_qc_sample_id
# HG002_downsampled          HG002
# HG002_full_v0.14           HG002
# HG00438                  HG00438
# HG005                      HG005
# HG00621                  HG00621
#
#                                                      mat_contam_results
# initial_qc_sample_id
# HG002_downsampled     gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG002_full_v0.14      gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00438               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG005                 gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00621               gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...

# %%
! mkdir vecscreen_results
# %cd vecscreen_results
# Out:
# mkdir: cannot create directory ‘vecscreen_results’: File exists
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit/vecscreen_results

# %% [markdown]
# ## Read In Decontamination Results; Extract VecScreen Hits & Write As BED

# %%
for index, row in decont_results_df.iterrows():
    
    sample_id = row.name
    
    ## Get path to decontamination results
    mat_decont_results_fp = row['mat_contam_results']
    pat_decont_results_fp = row['pat_contam_results']
    
    ## Extract file names
    mat_decont_results_fn = os.path.basename(mat_decont_results_fp)
    pat_decont_results_fn = os.path.basename(pat_decont_results_fp)
    
    ## Copy files to VM
    ! gsutil cp {mat_decont_results_fp} .
    ! gsutil cp {pat_decont_results_fp} .
    
    ## output bed file names
    mat_decont_bed_fn = sample_id + ".mat_decontam_results.bed"
    pat_decont_bed_fn = sample_id + ".pat_decontam_results.bed"
    
    ## Extract results and write bed file
    write_vecscreen_bed(mat_decont_results_fn, mat_decont_bed_fn)
    write_vecscreen_bed(pat_decont_results_fn, pat_decont_bed_fn)
# Out:
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002_downsampled.mat.contamination.short...
# / [1 files][  864.0 B/  864.0 B]
# Operation completed over 1 objects/864.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002_downsampled.pat.contamination.short...
# / [1 files][499.0 KiB/499.0 KiB]
# Operation completed over 1 objects/499.0 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002-full-0.14.mat.contamination.short...
# / [1 files][364.3 KiB/364.3 KiB]
# Operation completed over 1 objects/364.3 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG002-full-0.14.pat.contamination.short...
# / [1 files][  3.9 MiB/  3.9 MiB]
# Operation completed over 1 objects/3.9 MiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00438.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00438.pat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG005.mat.contamination.short...
# / [1 files][  6.2 KiB/  6.2 KiB]
# Operation completed over 1 objects/6.2 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG005.pat.contamination.short...
# / [1 files][  453.0 B/  453.0 B]
# Operation completed over 1 objects/453.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00621.mat.contamination.short...
# / [1 files][  496.0 B/  496.0 B]
# Operation completed over 1 objects/496.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00621.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00673.mat.contamination.short...
# / [1 files][  495.0 B/  495.0 B]
# Operation completed over 1 objects/495.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00673.pat.contamination.short...
# / [1 files][  271.0 B/  271.0 B]
# Operation completed over 1 objects/271.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00733.mat.contamination.short...
# / [1 files][111.6 KiB/111.6 KiB]
# Operation completed over 1 objects/111.6 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00733.pat.contamination.short...
# / [1 files][111.6 KiB/111.6 KiB]
# Operation completed over 1 objects/111.6 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00735.mat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00735.pat.contamination.short...
# / [1 files][   97.0 B/   97.0 B]
# Operation completed over 1 objects/97.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00741.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG00741.pat.contamination.short...
# / [1 files][   93.0 B/   93.0 B]
# Operation completed over 1 objects/93.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01071.mat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01071.pat.contamination.short...
# / [1 files][   92.0 B/   92.0 B]
# Operation completed over 1 objects/92.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01106.mat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01106.pat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01109.mat.contamination.short...
# / [1 files][  257.0 B/  257.0 B]
# Operation completed over 1 objects/257.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01109.pat.contamination.short...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01123.mat.contamination.short...
# / [1 files][  999.0 B/  999.0 B]
# Operation completed over 1 objects/999.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01123.pat.contamination.short...
# / [1 files][  220.0 B/  220.0 B]
# Operation completed over 1 objects/220.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01175.mat.contamination.short...
# / [1 files][  317.0 B/  317.0 B]
# Operation completed over 1 objects/317.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01175.pat.contamination.short...
# / [1 files][  126.0 B/  126.0 B]
# Operation completed over 1 objects/126.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01243.mat.contamination.short...
# / [1 files][  598.0 B/  598.0 B]
# Operation completed over 1 objects/598.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01243.pat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01258.mat.contamination.short...
# / [1 files][  1.0 KiB/  1.0 KiB]
# Operation completed over 1 objects/1.0 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01258.pat.contamination.short...
# / [1 files][  222.0 B/  222.0 B]
# Operation completed over 1 objects/222.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01358.mat.contamination.short...
# / [1 files][  1.3 KiB/  1.3 KiB]
# Operation completed over 1 objects/1.3 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01358.pat.contamination.short...
# / [1 files][   97.0 B/   97.0 B]
# Operation completed over 1 objects/97.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01361.mat.contamination.short...
# / [1 files][  631.0 B/  631.0 B]
# Operation completed over 1 objects/631.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01361.pat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01891.mat.contamination.short...
# / [1 files][  697.0 B/  697.0 B]
# Operation completed over 1 objects/697.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01891.pat.contamination.short...
# / [1 files][   96.0 B/   96.0 B]
# Operation completed over 1 objects/96.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01928.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01928.pat.contamination.short...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01952.mat.contamination.short...
# / [1 files][  193.0 B/  193.0 B]
# Operation completed over 1 objects/193.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01952.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01978.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG01978.pat.contamination.short...
# / [1 files][   95.0 B/   95.0 B]
# Operation completed over 1 objects/95.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02055.mat.contamination.short...
# / [1 files][  999.0 B/  999.0 B]
# Operation completed over 1 objects/999.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02055.pat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02080.mat.contamination.short...
# / [1 files][  392.0 B/  392.0 B]
# Operation completed over 1 objects/392.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02080.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02109.mat.contamination.short...
# / [1 files][  195.0 B/  195.0 B]
# Operation completed over 1 objects/195.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02109.pat.contamination.short...
# / [1 files][  138.0 B/  138.0 B]
# Operation completed over 1 objects/138.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02145.mat.contamination.short...
# / [1 files][  357.0 B/  357.0 B]
# Operation completed over 1 objects/357.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02145.pat.contamination.short...
# / [1 files][  257.0 B/  257.0 B]
# Operation completed over 1 objects/257.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02148.mat.contamination.short...
# / [1 files][  737.0 B/  737.0 B]
# Operation completed over 1 objects/737.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02148.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02257.mat.contamination.short...
# / [1 files][  626.0 B/  626.0 B]
# Operation completed over 1 objects/626.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02257.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02486.mat.contamination.short...
# / [1 files][   1005 B/   1005 B]
# Operation completed over 1 objects/1005.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02486.pat.contamination.short...
# / [1 files][   93.0 B/   93.0 B]
# Operation completed over 1 objects/93.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02559.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02559.pat.contamination.short...
# / [1 files][  224.0 B/  224.0 B]
# Operation completed over 1 objects/224.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02572.mat.contamination.short...
# / [1 files][  903.0 B/  903.0 B]
# Operation completed over 1 objects/903.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02572.pat.contamination.short...
# / [1 files][  222.0 B/  222.0 B]
# Operation completed over 1 objects/222.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02622.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02622.pat.contamination.short...
# / [1 files][   96.0 B/   96.0 B]
# Operation completed over 1 objects/96.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02630.mat.contamination.short...
# / [1 files][  930.0 B/  930.0 B]
# Operation completed over 1 objects/930.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02630.pat.contamination.short...
# / [1 files][  223.0 B/  223.0 B]
# Operation completed over 1 objects/223.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02717.mat.contamination.short...
# / [1 files][  1.5 KiB/  1.5 KiB]
# Operation completed over 1 objects/1.5 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02717.pat.contamination.short...
# / [1 files][   94.0 B/   94.0 B]
# Operation completed over 1 objects/94.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02723.mat.contamination.short...
# / [1 files][  739.0 B/  739.0 B]
# Operation completed over 1 objects/739.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02723.pat.contamination.short...
# / [1 files][  143.0 B/  143.0 B]
# Operation completed over 1 objects/143.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02818.mat.contamination.short...
# / [1 files][  1.8 KiB/  1.8 KiB]
# Operation completed over 1 objects/1.8 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02818.pat.contamination.short...
# / [1 files][  118.0 B/  118.0 B]
# Operation completed over 1 objects/118.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02886.mat.contamination.short...
# / [1 files][  1.8 KiB/  1.8 KiB]
# Operation completed over 1 objects/1.8 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG02886.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03098.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03098.pat.contamination.short...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03453.mat.contamination.short...
# / [1 files][  765.0 B/  765.0 B]
# Operation completed over 1 objects/765.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03453.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03486.mat.contamination.short...
# / [1 files][  946.0 B/  946.0 B]
# Operation completed over 1 objects/946.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03486.pat.contamination.short...
# / [1 files][  304.0 B/  304.0 B]
# Operation completed over 1 objects/304.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03492.mat.contamination.short...
# / [1 files][  590.0 B/  590.0 B]
# Operation completed over 1 objects/590.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03492.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03516.mat.contamination.short...
# / [1 files][  531.0 B/  531.0 B]
# Operation completed over 1 objects/531.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03516.pat.contamination.short...
# / [1 files][  225.0 B/  225.0 B]
# Operation completed over 1 objects/225.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03540.mat.contamination.short...
# / [1 files][  729.0 B/  729.0 B]
# Operation completed over 1 objects/729.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03540.pat.contamination.short...
# / [1 files][   97.0 B/   97.0 B]
# Operation completed over 1 objects/97.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03579.mat.contamination.short...
# / [1 files][  692.0 B/  692.0 B]
# Operation completed over 1 objects/692.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/HG03579.pat.contamination.short...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA18906.mat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA18906.pat.contamination.short...
# / [1 files][  128.0 B/  128.0 B]
# Operation completed over 1 objects/128.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA19240.mat.contamination.short...
# / [1 files][  1.6 KiB/  1.6 KiB]
# Operation completed over 1 objects/1.6 KiB.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA19240.pat.contamination.short...
# / [1 files][  280.0 B/  280.0 B]
# Operation completed over 1 objects/280.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA20129.mat.contamination.short...
# / [1 files][  615.0 B/  615.0 B]
# Operation completed over 1 objects/615.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA20129.pat.contamination.short...
# / [1 files][  127.0 B/  127.0 B]
# Operation completed over 1 objects/127.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA21309.mat.contamination.short...
# / [1 files][  868.0 B/  868.0 B]
# Operation completed over 1 objects/868.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/kerstin_decontam_results/NA21309.pat.contamination.short...
# / [1 files][  169.0 B/  169.0 B]
# Operation completed over 1 objects/169.0 B.

# %%
## Check how many files we have: expect 4 * 48 = 192
! ls | wc -l
# Out:
# 192

# %% [markdown]
# # Extract Adapter Hits From minimap2 PAFs

# %%
# %cd ..
! mkdir minimap2_results
# %cd minimap2_results
# Out:
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit
# mkdir: cannot create directory ‘minimap2_results’: File exists
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit/minimap2_results

# %% [markdown]
# ## Install BedTools

# %%
# %%capture
! wget https://github.com/arq5x/bedtools2/releases/download/v2.29.2/bedtools.static.binary

# %%
! mv bedtools.static.binary bedtools
! chmod a+x bedtools

# %% [markdown]
# ## Extract PAFs & Write BED Files For Maternal Haplotypes

# %%
for index, row in decont_results_df.iterrows():
    
    sample_id = row.name
    
    ## Copy down paf file
    mat_paf_gz_fp = row['mat_adapter_paf']
    ! gsutil cp {mat_paf_gz_fp} ./

    ## get paf file name and set bed file name
    mat_paf_fn          = os.path.basename(mat_paf_gz_fp)
    mat_minimap2_bed_fn = sample_id + ".mat.minimap2_results.bed"
    
    ## If file is empty write blank bed file
    if gz_size(mat_paf_fn) == 0:
        ! touch {mat_minimap2_bed_fn}
       
    else:
        ## create bed file from paf hits. Only pull hits with 0, 1, or 2 mismatches
        ## hits must be over 42nt long. Merge hits.
        ! zcat {mat_paf_fn} | grep -P "NM:i:0\t|NM:i:1\t|NM:i:2\t" | awk '$4-$3>=42' | cut -f6,8,9 | sort -k1,1 -k2,2n | ./bedtools merge > {mat_minimap2_bed_fn}
        
        ## Since wea are converting from PAF to BED stop needs to add 1 nt; start is same
        ! awk -v OFS='\t' '$3+=1' {mat_minimap2_bed_fn} > tmp && mv tmp {mat_minimap2_bed_fn}
# Out:
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/3941d23e-3dcc-4816-99ba-06dcae427199/call-alignAndGzip/HG002_downsampled.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/ff9d6990-2fff-4a8d-9fbe-ce8485f04b87/call-alignAndGzip/HG002_full_v0.14.paf.gz...
# / [1 files][  364.0 B/  364.0 B]
# Operation completed over 1 objects/364.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/23b2e0ab-b2d5-4a1a-af57-a6159f3c68b7/call-alignAndGzip/HG00438.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/ac339e45-114c-41f1-b1b6-405ddf636aaa/call-alignAndGzip/HG005.paf.gz...
# / [1 files][  325.0 B/  325.0 B]
# Operation completed over 1 objects/325.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/f7cd8992-497d-48fb-920d-6238cc36aac2/call-alignAndGzip/HG00621.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/15b3d649-1683-40c6-899d-93c141e05aa0/call-alignAndGzip/HG00673.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2
0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/1f22fbfe-c4d4-48da-ae31-5c4a45f4225b/call-alignAndGzip/HG03492.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/8f2489d4-b087-4427-a75b-783a690b9783/call-alignAndGzip/HG03516.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/3fd888f3-f202-421e-b5b9-4ec74ce556c8/call-alignAndGzip/HG03540.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/4110bf29-cea2-429e-b5c2-c62c2f98f7c8/call-alignAndGzip/HG03579.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/cdac8a14-0518-479d-820a-4a976e11e8b7/call-alignAndGzip/NA18906.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/0bbe2f35-0326-4649-89b9-0eed9ed7d3e5/call-alignAndGzip/NA19240.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/a7022378-8735-46cc-bcd4-11fb48f04d5a/call-alignAndGzip/NA20129.paf.gz...
# / [1 files][  197.0 B/  197.0 B]
# Operation completed over 1 objects/197.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/deb35c1a-b583-44aa-9db2-24c66c47a0a7/minimap2/b6e09375-f9d1-4e56-9079-e9dd8e505f43/call-alignAndGzip/NA21309.paf.gz...
# / [1 files][  179.0 B/  179.0 B]
# Operation completed over 1 objects/179.0 B.

# %% [markdown]
# ## Extract PAFs & Write BED Files For Paternal Haplotypes

# %%
for index, row in decont_results_df.iterrows():
    
    sample_id = row.name
    
    ## Copy down paf file
    pat_paf_gz_fp = row['pat_adapter_paf']
    ! gsutil cp {pat_paf_gz_fp} ./

    ## get paf file name and set bed file name
    pat_paf_fn          = os.path.basename(pat_paf_gz_fp)
    pat_minimap2_bed_fn = sample_id + ".pat.minimap2_results.bed"
    
    ## If file is empty write blank bed file
    if gz_size(pat_paf_fn) == 0:
        ! touch {pat_minimap2_bed_fn}
       
    else:   
        ## create bed file from paf hits. Only pull hits with 0, 1, or 2 mismatches
        ## hits must be over 42nt long. Merge hits.
        ! zcat {pat_paf_fn} | grep -P "NM:i:0\t|NM:i:1\t|NM:i:2\t" | awk '$4-$3>=42' | cut -f6,8,9 | sort -k1,1 -k2,2n | ./bedtools merge > {pat_minimap2_bed_fn}
        
        ## Converting from PAF to BED (stop needs to add 1nt; start is same)
        ! awk -v OFS='\t' '$3+=1' {pat_minimap2_bed_fn} > tmp && mv tmp {pat_minimap2_bed_fn}
# Out:
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/ad00620a-6680-4a86-bb4b-c11efdbbf738/call-alignAndGzip/HG002_downsampled.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/d2685f92-1f2e-49b4-bef4-e25768089b49/call-alignAndGzip/HG002_full_v0.14.paf.gz...
# / [1 files][  194.0 B/  194.0 B]
# Operation completed over 1 objects/194.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/53efbea7-4fd1-4d9d-a838-cc9778d96db4/call-alignAndGzip/HG00438.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/f8503d2a-2dca-4c4d-83cf-0d9029fd0e2e/call-alignAndGzip/HG005.paf.gz...
# / [1 files][  324.0 B/  324.0 B]
# Operation completed over 1 objects/324.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/651ff1de-4239-4ba1-9e31-d0327a93b5d8/call-alignAndGzip/HG00621.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/2ee4553d-8601-4a9b-bdaf-fda3945d6de9/call-alignAndGzip/HG00673.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/bd5a0e70-19e6-43ea-895e-4f6ba2d973f5/call-alignAndGzip/HG00733.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/c14699a0-d179-47b0-811b-fea1f69d7a14/call-alignAndGzip/HG00735.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/6020da19-1c1b-4e4b-a430-ccd8498766db/call-alignAndGzip/HG00741.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/da2900d2-67ad-4f84-9226-62d4e2a32c8a/call-alignAndGzip/HG01071.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2
paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/3ee0f42d-b9b3-4345-86c2-82e5be99ad7a/call-alignAndGzip/NA19240.paf.gz...
# / [1 files][  183.0 B/  183.0 B]
# Operation completed over 1 objects/183.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/55065a8e-08ac-4ea6-a1e0-998a9e574481/call-alignAndGzip/NA20129.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/9435229a-fdae-4132-82b1-7588e04550e9/minimap2/6a595fe2-9dc2-4cec-bd12-0b1dbd528c63/call-alignAndGzip/NA21309.paf.gz...
# / [1 files][  204.0 B/  204.0 B]
# Operation completed over 1 objects/204.0 B.

# %% [markdown]
# # Combine Adapter Hits From VecScreen + minimap2

# %%
# %cd ..
! mkdir combined_beds
# %cd combined_beds
# Out:
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit
# mkdir: cannot create directory ‘combined_beds’: File exists
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit/combined_beds

# %%
for index, row in decont_results_df.iterrows():
    
    sample_id = row.name

    
    ## Get file names for the files we created above
    mat_decont_bed_fn   = "../vecscreen_results/" + sample_id + ".mat_decontam_results.bed"
    pat_decont_bed_fn   = "../vecscreen_results/" + sample_id + ".pat_decontam_results.bed"

    pat_minimap2_bed_fn = "../minimap2_results/" + sample_id + ".pat.minimap2_results.bed"
    mat_minimap2_bed_fn = "../minimap2_results/" + sample_id + ".mat.minimap2_results.bed"
    
    
    ## Create file names for combined bed files
    mat_tmp_bed_fn   = sample_id + ".mat_comb_unmerged.bed"
    pat_tmp_bed_fn   = sample_id + ".pat_comb_unmerged.bed"   
    
    mat_comb_bed_fn   = sample_id + ".mat_adapter.bed"
    pat_comb_bed_fn   = sample_id + ".pat_adapter.bed"
    
    
    ## combine bed files
    ! cat {mat_decont_bed_fn} {mat_minimap2_bed_fn} | sort -k1,1 -k2,2n > {mat_tmp_bed_fn}
    ! cat {pat_decont_bed_fn} {pat_minimap2_bed_fn} | sort -k1,1 -k2,2n > {pat_tmp_bed_fn}
    
    ## Merge 
    ! ../minimap2_results/bedtools merge -i {mat_tmp_bed_fn} -d 5 > {mat_comb_bed_fn}
    ! ../minimap2_results/bedtools merge -i {pat_tmp_bed_fn} -d 5 > {pat_comb_bed_fn}    
    
    ## upload to bucket
    ! gsutil cp {mat_comb_bed_fn} {bucket}adapter_work/sample_beds/{mat_comb_bed_fn}
    ! gsutil cp {pat_comb_bed_fn} {bucket}adapter_work/sample_beds/{pat_comb_bed_fn}
# Out:
# Copying file://HG002_downsampled.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG002_downsampled.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG002_full_v0.14.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][  129.0 B/  129.0 B]
# Operation completed over 1 objects/129.0 B.
# Copying file://HG002_full_v0.14.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   95.0 B/   95.0 B]
# Operation completed over 1 objects/95.0 B.
# Copying file://HG00438.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00438.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG005.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][  135.0 B/  135.0 B]
# Operation completed over 1 objects/135.0 B.
# Copying file://HG005.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][  115.0 B/  115.0 B]
# Operation completed over 1 objects/115.0 B.
# Copying file://HG00621.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00621.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00673.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00673.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   58.0 B/   58.0 B]
# Operation completed over 1 objects/58.0 B.
# Copying file://HG00733.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG00733.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG00735.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG00735.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG00741.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG00741.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   26.0 B/   26.0 B]
# Operation completed over 1 objects/26.0 B.
# Copying file://HG01071.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01071.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   26.0 B/   26.0 B]
# Operation completed over 1 objects/26.0 B.
# Copying file://HG01106.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG01106.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01109.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG01109.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG01123.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG01123.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   26.0 B/   26.0 B]
# Operation completed over 1 objects/26.0 B.
# Copying file://HG01175.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   86.0 B/   86.0 B]
# Operation completed over 1 objects/86.0 B.
# Copying file://HG01175.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01243.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01243.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG01258.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG01258.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG01358.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG01358.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG01361.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01361.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG01891.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG01891.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG01928.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01928.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG01952.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01952.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01978.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG01978.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02055.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02055.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02080_split.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG02080_split.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02109.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02109.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   54.0 B/   54.0 B]
# Operation completed over 1 objects/54.0 B.
# Copying file://HG02145.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02145.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02148.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02148.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02257.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   26.0 B/   26.0 B]
# Operation completed over 1 objects/26.0 B.
# Copying file://HG02257.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02486.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG02486.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   26.0 B/   26.0 B]
# Operation completed over 1 objects/26.0 B.
# Copying file://HG02559.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02559.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG02572.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG02572.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02622.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02622.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG02630.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02630.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02717.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02717.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02723.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   56.0 B/   56.0 B]
# Operation completed over 1 objects/56.0 B.
# Copying file://HG02723.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   58.0 B/   58.0 B]
# Operation completed over 1 objects/58.0 B.
# Copying file://HG02818.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG02818.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   37.0 B/   37.0 B]
# Operation completed over 1 objects/37.0 B.
# Copying file://HG02886.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG02886.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03098.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03098.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG03453.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG03453.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03486.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   58.0 B/   58.0 B]
# Operation completed over 1 objects/58.0 B.
# Copying file://HG03486.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   56.0 B/   56.0 B]
# Operation completed over 1 objects/56.0 B.
# Copying file://HG03492.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG03492.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03516.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://HG03516.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG03540.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG03540.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   30.0 B/   30.0 B]
# Operation completed over 1 objects/30.0 B.
# Copying file://HG03579.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://HG03579.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://NA18906.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://NA18906.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://NA19240.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   28.0 B/   28.0 B]
# Operation completed over 1 objects/28.0 B.
# Copying file://NA19240.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][  114.0 B/  114.0 B]
# Operation completed over 1 objects/114.0 B.
# Copying file://NA20129.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   18.0 B/   18.0 B]
# Operation completed over 1 objects/18.0 B.
# Copying file://NA20129.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][    0.0 B/    0.0 B]
# Operation completed over 1 objects.
# Copying file://NA21309.mat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   69.0 B/   69.0 B]
# Operation completed over 1 objects/69.0 B.
# Copying file://NA21309.pat_adapter.bed [Content-Type=application/octet-stream]...
# / [1 files][   97.0 B/   97.0 B]
# Operation completed over 1 objects/97.0 B.

# %% [markdown]
# **Add columns for the adapter beds**

# %%
decont_results_df['mat_adapter_bed'] = f"{bucket}adapter_work/sample_beds/" + decont_results_df.index + ".mat_adapter.bed"
decont_results_df['pat_adapter_bed'] = f"{bucket}adapter_work/sample_beds/" + decont_results_df.index + ".pat_adapter.bed"

# %% [markdown]
# # Look At How Many Adapter Hits We Are Finding

# %%
## Set bed column names
bed_col_names = ["contig", "start", "stop"]

# %%
track_results_df = decont_results_df.copy()


track_results_df.drop(columns = ["pat_contam_results", "pat_adapter_paf", "hifiasm_mat_fa", "mat_adapter_bed", 
                                 "pat_adapter_bed", "hifiasm_pat_fa", "mat_adapter_paf", "mat_contam_results"],
                      inplace = True)


new_column_ls = ['mat_decon_num_adapter_hit', 'mat_decon_num_contigs_w_ad', 'mat_decon_bp_adapter_seq',
                 'pat_decon_num_adapter_hit', 'pat_decon_num_contigs_w_ad', 'pat_decon_bp_adapter_seq',
                 'mat_minimap_num_adapter_hit', 'mat_minimap_num_contigs_w_ad', 'mat_minimap_bp_adapter_seq',
                 'pat_minimap_num_adapter_hit', 'pat_minimap_num_contigs_w_ad', 'pat_minimap_bp_adapter_seq']


for new_column in new_column_ls:
    track_results_df[new_column] = 0

# %%
for index, row in track_results_df.iterrows():
    
    sample_id = row.name

    
    ## Get file names for the files we created above
    mat_decont_bed_fn   = "../vecscreen_results/" + sample_id + ".mat_decontam_results.bed"
    pat_decont_bed_fn   = "../vecscreen_results/" + sample_id + ".pat_decontam_results.bed"

    pat_minimap2_bed_fn = "../minimap2_results/" + sample_id + ".pat.minimap2_results.bed"
    mat_minimap2_bed_fn = "../minimap2_results/" + sample_id + ".mat.minimap2_results.bed"


    ## Maternal Decon Pipeline Hits
    mat_hits_bed_df = pd.read_csv(mat_decont_bed_fn, sep='\t', names=bed_col_names)

    track_results_df.loc[index, 'mat_decon_num_adapter_hit']  = len(mat_hits_bed_df.index)
    track_results_df.loc[index, 'mat_decon_num_contigs_w_ad'] = mat_hits_bed_df['contig'].nunique()
    track_results_df.loc[index, 'mat_decon_bp_adapter_seq']   = sum(mat_hits_bed_df['stop'] - mat_hits_bed_df['start'])
    
    
    ## paternal Decon Pipeline Hits
    pat_hits_bed_df = pd.read_csv(pat_decont_bed_fn, sep='\t', names=bed_col_names)

    track_results_df.loc[index, 'pat_decon_num_adapter_hit']  = len(pat_hits_bed_df.index)
    track_results_df.loc[index, 'pat_decon_num_contigs_w_ad'] = pat_hits_bed_df['contig'].nunique()
    track_results_df.loc[index, 'pat_decon_bp_adapter_seq']   = sum(pat_hits_bed_df['stop'] - pat_hits_bed_df['start'])
    
    
    ## Maternal minimap2 Hits
    mat_hits_bed_df = pd.read_csv(mat_minimap2_bed_fn, sep='\t', names=bed_col_names)

    track_results_df.loc[index, 'mat_minimap_num_adapter_hit']  = len(mat_hits_bed_df.index)
    track_results_df.loc[index, 'mat_minimap_num_contigs_w_ad'] = mat_hits_bed_df['contig'].nunique()
    track_results_df.loc[index, 'mat_minimap_bp_adapter_seq']   = sum(mat_hits_bed_df['stop'] - mat_hits_bed_df['start'])
    
    
    ## paternal minimap2 Hits
    pat_hits_bed_df = pd.read_csv(pat_minimap2_bed_fn, sep='\t', names=bed_col_names)

    ## Set paternal number of hits in data frame
    track_results_df.loc[index, 'pat_minimap_num_adapter_hit']  = len(pat_hits_bed_df.index)
    track_results_df.loc[index, 'pat_minimap_num_contigs_w_ad'] = pat_hits_bed_df['contig'].nunique()
    track_results_df.loc[index, 'pat_minimap_bp_adapter_seq']   = sum(pat_hits_bed_df['stop'] - pat_hits_bed_df['start'])

# %%
track_results_df
# Out:
#                      sample_name  mat_decon_num_adapter_hit  \
# initial_qc_sample_id
# HG002_downsampled          HG002                          1
# HG002_full_v0.14           HG002                          4
# HG00438                  HG00438                          0
# HG005                      HG005                          7
# HG00621                  HG00621                          0
# HG00673                  HG00673                          0
# HG00733                  HG00733                          1
# HG00735                  HG00735                          1
# HG00741                  HG00741                          0
# HG01071                  HG01071                          0
# HG01106                  HG01106                          1
# HG01109                  HG01109                          1
# HG01123                  HG01123                          1
# HG01175                  HG01175                          3
# HG01243                  HG01243                          0
# HG01258                  HG01258                          1
# HG01358                  HG01358                          1
# HG01361                  HG01361                          0
# HG01891                  HG01891                          1
# HG01928                  HG01928                          0
# HG01952                  HG01952                          0
# HG01978                  HG01978                          0
# HG02055                  HG02055                          1
# HG02080_split            HG02080                          1
# HG02109                  HG02109                          0
# HG02145                  HG02145                          1
# HG02148                  HG02148                          0
# HG02257                  HG02257                          1
# HG02486                  HG02486                          1
# HG02559                  HG02559                          0
# HG02572                  HG02572                          1
# HG02622                  HG02622                          0
# HG02630                  HG02630                          1
# HG02717                  HG02717                          1
# HG02723                  HG02723                          2
# HG02818                  HG02818                          1
# HG02886                  HG02886                          0
# HG03098                  HG03098                          0
# HG03453                  HG03453                          1
# HG03486                  HG03486                          2
# HG03492                  HG03492                          1
# HG03516                  HG03516                          0
# HG03540                  HG03540                          1
# HG03579                  HG03579                          1
# NA18906                  NA18906                          0
# NA19240                  NA19240                          1
# NA20129                  NA20129                          1
# NA21309                  NA21309                          3
#
#                       mat_decon_num_contigs_w_ad  mat_decon_bp_adapter_seq  \
# initial_qc_sample_id
# HG002_downsampled                              1                        26
# HG002_full_v0.14                               3                       148
# HG00438                                        0                         0
# HG005                                          5                       280
# HG00621                                        0                         0
# HG00673                                        0                         0
# HG00733                                        1                        26
# HG00735                                        1                        26
# HG00741                                        0                         0
# HG01071                                        0                         0
# HG01106                                        1                        26
# HG01109                                        1                        19
# HG01123                                        1                        26
# HG01175                                        1                       112
# HG01243                                        0                         0
# HG01258                                        1                        26
# HG01358                                        1                        26
# HG01361                                        0                         0
# HG01891                                        1                        26
# HG01928                                        0                         0
# HG01952                                        0                         0
# HG01978                                        0                         0
# HG02055                                        1                        34
# HG02080_split                                  1                        26
# HG02109                                        0                         0
# HG02145                                        1                        27
# HG02148                                        0                         0
# HG02257                                        1                        26
# HG02486                                        1                        26
# HG02559                                        0                         0
# HG02572                                        1                        36
# HG02622                                        0                         0
# HG02630                                        1                        27
# HG02717                                        1                        34
# HG02723                                        2                        60
# HG02818                                        1                        26
# HG02886                                        0                         0
# HG03098                                        0                         0
# HG03453                                        1                        26
# HG03486                                        2                       106
# HG03492                                        1                        26
# HG03516                                        0                         0
# HG03540                                        1                        26
# HG03579                                        1                        27
# NA18906                                        0                         0
# NA19240                                        1                        26
# NA20129                                        1                        37
# NA21309                                        3                       110
#
#                       pat_decon_num_adapter_hit  pat_decon_num_contigs_w_ad  \
# initial_qc_sample_id
# HG002_downsampled                             1                           1
# HG002_full_v0.14                              3                           3
# HG00438                                       1                           1
# HG005                                         6                           4
# HG00621                                       0                           0
# HG00673                                       2                           2
# HG00733                                       1                           1
# HG00735                                       1                           1
# HG00741                                       1                           1
# HG01071                                       1                           1
# HG01106                                       0                           0
# HG01109                                       1                           1
# HG01123                                       1                           1
# HG01175                                       0                           0
# HG01243                                       1                           1
# HG01258                                       1                           1
# HG01358                                       1                           1
# HG01361                                       1                           1
# HG01891                                       1                           1
# HG01928                                       1                           1
# HG01952                                       0                           0
# HG01978                                       1                           1
# HG02055                                       0                           0
# HG02080_split                                 0                           0
# HG02109                                       2                           2
# HG02145                                       1                           1
# HG02148                                       0                           0
# HG02257                                       0                           0
# HG02486                                       1                           1
# HG02559                                       1                           1
# HG02572                                       1                           1
# HG02622                                       1                           1
# HG02630                                       1                           1
# HG02717                                       1                           1
# HG02723                                       2                           2
# HG02818                                       2                           1
# HG02886                                       0                           0
# HG03098                                       1                           1
# HG03453                                       0                           0
# HG03486                                       2                           2
# HG03492                                       0                           0
# HG03516                                       1                           1
# HG03540                                       1                           1
# HG03579                                       0                           0
# NA18906                                       0                           0
# NA19240                                       5                           3
# NA20129                                       0                           0
# NA21309                                       3                           3
#
#                       pat_decon_bp_adapter_seq  mat_minimap_num_adapter_hit  \
# initial_qc_sample_id
# HG002_downsampled                           26                            0
# HG002_full_v0.14                            95                            2
# HG00438                                     26                            0
# HG005                                      256                            1
# HG00621                                      0                            0
# HG00673                                     61                            0
# HG00733                                     25                            0
# HG00735                                     27                            0
# HG00741                                     26                            0
# HG01071                                     26                            0
# HG01106                                      0                            0
# HG01109                                     26                            0
# HG01123                                     26                            0
# HG01175                                      0                            0
# HG01243                                     26                            0
# HG01258                                     26                            0
# HG01358                                     26                            0
# HG01361                                     26                            0
# HG01891                                     34                            0
# HG01928                                     26                            0
# HG01952                                      0                            0
# HG01978                                     26                            0
# HG02055                                      0                            0
# HG02080_split                                0                            0
# HG02109                                     70                            0
# HG02145                                     26                            0
# HG02148                                      0                            0
# HG02257                                      0                            0
# HG02486                                     26                            0
# HG02559                                     26                            0
# HG02572                                     26                            0
# HG02622                                     27                            0
# HG02630                                     26                            0
# HG02717                                     26                            0
# HG02723                                     60                            0
# HG02818                                     86                            0
# HG02886                                      0                            0
# HG03098                                     26                            0
# HG03453                                      0                            0
# HG03486                                     45                            0
# HG03492                                      0                            0
# HG03516                                     26                            0
# HG03540                                     26                            0
# HG03579                                      0                            0
# NA18906                                      0                            0
# NA19240                                    179                            0
# NA20129                                      0                            1
# NA21309                                     98                            1
#
#                       mat_minimap_num_contigs_w_ad  \
# initial_qc_sample_id
# HG002_downsampled                                0
# HG002_full_v0.14                                 2
# HG00438                                          0
# HG005                                            1
# HG00621                                          0
# HG00673                                          0
# HG00733                                          0
# HG00735                                          0
# HG00741                                          0
# HG01071                                          0
# HG01106                                          0
# HG01109                                          0
# HG01123                                          0
# HG01175                                          0
# HG01243                                          0
# HG01258                                          0
# HG01358                                          0
# HG01361                                          0
# HG01891                                          0
# HG01928                                          0
# HG01952                                          0
# HG01978                                          0
# HG02055                                          0
# HG02080_split                                    0
# HG02109                                          0
# HG02145                                          0
# HG02148                                          0
# HG02257                                          0
# HG02486                                          0
# HG02559                                          0
# HG02572                                          0
# HG02622                                          0
# HG02630                                          0
# HG02717                                          0
# HG02723                                          0
# HG02818                                          0
# HG02886                                          0
# HG03098                                          0
