# %% [markdown]
# # Write MT Contigs<a class="tocSkip">
#
# **In this notebook, we will parse the PAF files from mapping the MT contigs to the ref version of chrM. We will first select the "best" MT contig based on minimap2 alignments. After selecting the best MT contig for each sample, we will write that MT contig to a file (including reverse complementing the contig, if neccesary).**
#
#
# **The steps that we will take are:**
# 1. Import Statements & Global Variable Definitions
# 2. Load Data Table
# 3. Select Best MT Hits
# 4. Write MT Contigs

# %% [markdown]
# # Preparation

# %% [markdown]
# **Install Tools**

# %%
## Neccesary because GATK container comes with super old samtools (see note below)
# %%capture
# %pip install pyfaidx

# %%
# %%capture
# %pip install gcsfs

# %%
# %%capture
# %pip install --upgrade --no-cache-dir terra-pandas
# %pip install --upgrade --no-cache-dir terra-notebook-utils

# %%
# %%capture
# %pip install --no-cache-dir -U crcmod

# %% [markdown]
# **Import Libraries**

# %%
# %%capture 
import os
import io
import pandas as pd
import numpy as np
import gcsfs
import gzip

import terra_notebook_utils as tnu
import terra_pandas as tp
from pyfaidx import Fasta
from Bio import SeqIO
from Bio.Seq import Seq, Alphabet 
from Bio.SeqRecord import SeqRecord

# %% [markdown]
# **Find Workspace Info**

# %%
# Get the Google billing project name and workspace name
PROJECT   = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE = os.path.basename(os.path.dirname(os.getcwd()))
bucket    = os.environ['WORKSPACE_BUCKET'] + "/"

# Verify that we've captured the environment variables
print("Billing project: " + PROJECT)
print("Workspace: " + WORKSPACE)
print("Workspace storage bucket: " + bucket)
# Out:
# Billing project: human-pangenome-ucsc
# Workspace: HPRC_Reassembly
# Workspace storage bucket: gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/

# %% [markdown]
# ## Function Definitions

# %%
def gz_size(fname):
    with gzip.open(fname, 'rb') as f:
        return f.seek(0, whence=2)

# %% [markdown]
# # Load Data Table

# %%
clean_sample_df = tp.table_to_dataframe("clean_sample")

clean_sample_df.head()
# Out:
#                                                        mat_masked_fa  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/a...
#
#                                                 mito_against_ref_paf  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d...
#
#                                                pat_masked_cleaned_fa  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/3...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/3...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/3...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/3...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/3...
#
#                                                mat_masked_cleaned_fa  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/1...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/1...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/1...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/1...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/1...
#
#                                                   pat_mito_contig_ls  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
#
#                                                   pat_contam_results  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
#
#                                                   mat_mito_contig_ls  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/m...
#
#                                                       hifiasm_mat_fa  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                     all_mito_contigs  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/8...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/8...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/8...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/8...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/8...
#
#                                                       hifiasm_pat_fa  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/2...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/f...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                   sample_name  \
# clean_sample_id
# HG002_downsampled       HG002
# HG002_full_v0.14        HG002
# HG00438               HG00438
# HG005                   HG005
# HG00621               HG00621
#
#                                                     pat_drop_contigs  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                     mat_drop_contigs  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/c...
#
#                                                        pat_masked_fa  \
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/7...
#
#                                                   mat_contam_results
# clean_sample_id
# HG002_downsampled  gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG002_full_v0.14   gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00438            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG005              gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...
# HG00621            gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/k...

# %% [markdown]
# # Select Best MT Hits

# %%
! mkdir raw_contigs
# %cd raw_contigs
# Out:
# mkdir: cannot create directory ‘raw_contigs’: File exists
# /home/jupyter-user/notebooks/HPRC_Reassembly/edit/raw_contigs

# %%
## Set paf column names (incomplete)
paf_col_names = ["Query_sequence_name", "Query_sequence_length", "Query_start", "Query_end",
                 "Relative_strand", "Target_sequence_name","Target_sequence_length", "Target_start",
                 "Target_end", "Number_of_residue_matches", "Alignment_block_length", "Mapping_quality", 
                 "NM", "ms", "AS", "nn", "tp", "cm", "s1"]

# %%
## Create dataframe to hold best hits for each sample
all_results_df = pd.DataFrame()
no_good_hit_ls = []

for index, row in clean_sample_df.iterrows():
    
    sample_name        = row.name
    print(f"Pulling: {sample_name}")
    
    ## Pull PAF file with hits of mito contigs against chrM reference
    paf_fp = row['mito_against_ref_paf']
    paf_fn     = os.path.basename(paf_fp)
    
    ! gsutil cp {paf_fp} ./
    
    
    ## If the file is empty, then we don't have any hits
    if gz_size(paf_fn) == 0:
        no_good_hit_ls.append(sample_name)
    
    else:
        ## Pull only first 19 columns of paf (because later columns are inconsistent)
        cut_fn = f"{paf_fn}.cut"
        
        ! zcat {paf_fn} | cut -f 1-19 > {cut_fn}
        paf_df = pd.read_csv(cut_fn, sep='\t', names=paf_col_names)
        
        ## Add sample name
        paf_df['sample_name'] = sample_name
        
        ## Make sure to only pull from alignments which have long enough block lengths
        is_align_over_cutoff = paf_df['Alignment_block_length'] > 16560
        
        paf_df = paf_df[is_align_over_cutoff]
        paf_df = paf_df.reset_index()
            
        if paf_df.empty:
            no_good_hit_ls.append(sample_name)
        
        else:
            ## Extract Ints for NM (number of mismatches) & AS (DP alignment score)
            paf_df['NM_int'] = (paf_df['NM'].str.split(":", expand=True)[2])
            paf_df['NM_int'] = paf_df['NM_int'].astype('int32')

            paf_df['AS_int'] = (paf_df['AS'].str.split(":", expand=True)[2])
            paf_df['AS_int'] = paf_df['AS_int'].astype('int32')

            
            ## Find row(s) with highest alignment score and create new data frame
            AS_max           = paf_df['AS_int'].max()      
            is_AS_max_row    = paf_df['AS_int'] == AS_max
            
            max_df = paf_df.loc[(is_AS_max_row)]
            max_df = max_df.reset_index()

            
            ## Keep rows with lowest number of mismatches (and highest alignment score)
            all_results_df = all_results_df.append(max_df.iloc[max_df['NM_int'].idxmin()])
# Out:
# Pulling: HG002_downsampled
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/b507a11a-14da-493c-905f-c4aa50ff96a8/call-alignAndGzip/HG002_downsampled.paf.gz...
# / [1 files][  3.5 KiB/  3.5 KiB]
# Operation completed over 1 objects/3.5 KiB.
# Pulling: HG002_full_v0.14
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/607dc26b-98b6-4dca-b02f-cd83fbd3d1a5/call-alignAndGzip/HG002_full_v0.14.paf.gz...
# / [1 files][ 20.2 KiB/ 20.2 KiB]
# Operation completed over 1 objects/20.2 KiB.
# Pulling: HG00438
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/8f5fbd0c-7779-46c2-92ba-24723937a07d/call-alignAndGzip/HG00438.paf.gz...
# / [1 files][  437.0 B/  437.0 B]
# Operation completed over 1 objects/437.0 B.
# Pulling: HG005
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/ba46bdbd-2e67-4ae9-89a2-441b2255a64a/call-alignAndGzip/HG005.paf.gz...
# / [1 files][ 29.1 KiB/ 29.1 KiB]
# Operation completed over 1 objects/29.1 KiB.
# Pulling: HG00621
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/5b4d1760-5b63-4749-892b-206fd7a25f2b/call-alignAndGzip/HG00621.paf.gz...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# Pulling: HG00673
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/5945a767-d82c-438f-9c54-d4aadeb38602/call-alignAndGzip/HG00673.paf.gz...
# / [1 files][  4.3 KiB/  4.3 KiB]
# Operation completed over 1 objects/4.3 KiB.
# Pulling: HG00733
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/db5c079c-db58-4aef-bc90-3319af2a358f/call-alignAndGzip/HG00733.paf.gz...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Pulling: HG00735
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/d21351b5-72b2-4a41-82a7-424cef1eea6e/call-alignAndGzip/HG00735.paf.gz...
# / [1 files][  471.0 B/  471.0 B]
# Operation completed over 1 objects/471.0 B.
# Pulling: HG00741
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/92efb940-445e-4fae-a125-16bb0c478182/call-alignAndGzip/HG00741.paf.gz...
# / [1 files][  505.0 B/  505.0 B]
# Operation completed over 1 objects/505.0 B.
# Pulling: HG01071
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/90e478ba-3ac5-4e26-9327-ad097d8e9cc5/call-alignAndGzip/cacheCopy/HG01071.paf.gz...
# / [1 files][   20.0 B/   20.0 B]
# Operation completed over 1 objects/20.0 B.
# Pulling: HG01106
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/d1eb355c-136f-4878-beb0-291ce51dcb3a/call-alignAndGzip/HG01106.paf.gz...
# / [1 files][  421.0 B/  421.0 B]
# Operation completed over 1 objects/421.0 B.
# Pulling: HG01109
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/d0567b8d-6cea-4229-ad08-f375834949d3/call-alignAndGzip/HG01109.paf.gz...
# / [1 files][  693.0 B/  693.0 B]
# Operation completed over 1 objects/693.0 B.
# Pulling: HG01123
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/6cbccbc5-9e8a-4069-87a1-5271a0944dfa/call-alignAndGzip/HG01123.paf.gz...
# / [1 files][  6.3 KiB/  6.3 KiB]
# Operation completed over 1 objects/6.3 KiB.
# Pulling: HG01175
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/f1cd90d9-fd63-43d6-b24c-1915ee736820/call-alignAndGzip/HG01175.paf.gz...
# / [1 files][  368.0 B/  368.0 B]
# Operation completed over 1 objects/368.0 B.
# Pulling: HG01243
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/105cb4eb-855d-4e00-a050-aa986662e4c2/call-alignAndGzip/HG01243.paf.gz...
# / [1 files][  6.8 KiB/  6.8 KiB]
# Operation completed over 1 objects/6.8 KiB.
# Pulling: HG01258
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/3abde2d0-9bf2-414d-a06f-ff0918ead442/call-alignAndGzip/HG01258.paf.gz...
# / [1 files][  7.8 KiB/  7.8 KiB]
# Operation completed over 1 objects/7.8 KiB.
# Pulling: HG01358
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/c57ae4a1-97f2-48a3-8898-689a0cfea58f/call-alignAndGzip/HG01358.paf.gz...
# / [1 files][  9.4 KiB/  9.4 KiB]
# Operation completed over 1 objects/9.4 KiB.
# Pulling: HG01361
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/db1959c3-d9f0-4d86-9092-440f4c73da7c/call-alignAndGzip/HG01361.paf.gz...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Pulling: HG01891
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/f5f55e86-23ca-43d8-944a-fca60c51f20a/call-alignAndGzip/HG01891.paf.gz...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# Pulling: HG01928
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/865ef112-c12a-4aca-87b4-4493abcf9cc7/call-alignAndGzip/HG01928.paf.gz...
# / [1 files][  422.0 B/  422.0 B]
# Operation completed over 1 objects/422.0 B.
# Pulling: HG01952
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/2a4e0e31-3b22-4260-a244-8d7b7e9eda1b/call-alignAndGzip/HG01952.paf.gz...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Pulling: HG01978
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/e1688686-d8ad-4b20-8547-88dd566d6b4a/call-alignAndGzip/HG01978.paf.gz...
# / [1 files][  331.0 B/  331.0 B]
# Operation completed over 1 objects/331.0 B.
# Pulling: HG02055
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/7ff48281-9fe9-43b0-9d40-f3b4041bb940/call-alignAndGzip/HG02055.paf.gz...
# / [1 files][  7.8 KiB/  7.8 KiB]
# Operation completed over 1 objects/7.8 KiB.
# Pulling: HG02080_split
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/bfd97e06-d2b9-444a-a9c8-d67a37768f24/call-alignAndGzip/HG02080_split.paf.gz...
# / [1 files][  3.8 KiB/  3.8 KiB]
# Operation completed over 1 objects/3.8 KiB.
# Pulling: HG02109
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/648fb3f1-91e7-4571-9044-633394caaee0/call-alignAndGzip/HG02109.paf.gz...
# / [1 files][  961.0 B/  961.0 B]
# Operation completed over 1 objects/961.0 B.
# Pulling: HG02145
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/4817b297-11a3-445a-9531-ddcd0de9a1bb/call-alignAndGzip/HG02145.paf.gz...
# / [1 files][  2.2 KiB/  2.2 KiB]
# Operation completed over 1 objects/2.2 KiB.
# Pulling: HG02148
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/953625f8-211f-49d1-b780-95830441385b/call-alignAndGzip/HG02148.paf.gz...
# / [1 files][  6.5 KiB/  6.5 KiB]
# Operation completed over 1 objects/6.5 KiB.
# Pulling: HG02257
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/52a208a2-1a8d-4123-8a14-73a6b63f852a/call-alignAndGzip/HG02257.paf.gz...
# / [1 files][  3.7 KiB/  3.7 KiB]
# Operation completed over 1 objects/3.7 KiB.
# Pulling: HG02486
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/e193fad1-78eb-4242-9458-f00c3029a0f0/call-alignAndGzip/HG02486.paf.gz...
# / [1 files][  7.7 KiB/  7.7 KiB]
# Operation completed over 1 objects/7.7 KiB.
# Pulling: HG02559
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/e1044a55-dcdc-4c09-8285-dd649765793c/minimap2/ea85b071-0db1-4cc1-92ac-70c07a596846/call-alignAndGzip/HG02559.paf.gz...
# / [1 files][  427.0 B/  427.0 B]
# Operation completed over 1 objects/427.0 B.
# Pulling: HG02572
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/7caa609f-d103-4243-8705-ee4708322040/call-alignAndGzip/HG02572.paf.gz...
# / [1 files][  7.2 KiB/  7.2 KiB]
# Operation completed over 1 objects/7.2 KiB.
# Pulling: HG02622
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/4d548af4-3a4e-4a57-9f38-5ed22f5c381b/call-alignAndGzip/HG02622.paf.gz...
# / [1 files][  382.0 B/  382.0 B]
# Operation completed over 1 objects/382.0 B.
# Pulling: HG02630
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/0f0cdec7-4cbb-4a4a-9411-6c0ed9438304/call-alignAndGzip/HG02630.paf.gz...
# / [1 files][  6.0 KiB/  6.0 KiB]
# Operation completed over 1 objects/6.0 KiB.
# Pulling: HG02717
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/f689cafb-e702-4f54-9981-ca6fb5343e94/call-alignAndGzip/HG02717.paf.gz...
# / [1 files][ 10.5 KiB/ 10.5 KiB]
# Operation completed over 1 objects/10.5 KiB.
# Pulling: HG02723
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/16609376-86e7-45d4-b355-9d69235688a2/call-alignAndGzip/HG02723.paf.gz...
# / [1 files][  6.6 KiB/  6.6 KiB]
# Operation completed over 1 objects/6.6 KiB.
# Pulling: HG02818
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/5082df50-85cb-4076-bc30-304130ecc196/call-alignAndGzip/HG02818.paf.gz...
# / [1 files][ 10.8 KiB/ 10.8 KiB]
# Operation completed over 1 objects/10.8 KiB.
# Pulling: HG02886
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/ad64283b-3d5b-4049-aa2e-dbb0b83d0fde/call-alignAndGzip/HG02886.paf.gz...
# / [1 files][ 11.1 KiB/ 11.1 KiB]
# Operation completed over 1 objects/11.1 KiB.
# Pulling: HG03098
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/1b7ecbdd-4f2e-4873-b9d1-6fed001ca700/minimap2/bf6a209e-b0ac-4d54-b746-286b2c7437f6/call-alignAndGzip/HG03098.paf.gz...
# / [1 files][  446.0 B/  446.0 B]
# Operation completed over 1 objects/446.0 B.
# Pulling: HG03453
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/0a7bf91a-98f6-4a36-97cf-1c8eaeb8a8ad/call-alignAndGzip/HG03453.paf.gz...
# / [1 files][  5.9 KiB/  5.9 KiB]
# Operation completed over 1 objects/5.9 KiB.
# Pulling: HG03486
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/23959ac3-25a0-489a-a1d1-4638e25bb235/call-alignAndGzip/HG03486.paf.gz...
# / [1 files][  5.7 KiB/  5.7 KiB]
# Operation completed over 1 objects/5.7 KiB.
# Pulling: HG03492
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/03b2ec9a-7ba4-42b1-8781-0dc9cfd2aa5b/call-alignAndGzip/HG03492.paf.gz...
# / [1 files][  5.2 KiB/  5.2 KiB]
# Operation completed over 1 objects/5.2 KiB.
# Pulling: HG03516
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/10dda4f9-ca84-4aee-8c97-6bbef76ec6a3/call-alignAndGzip/HG03516.paf.gz...
# / [1 files][  5.2 KiB/  5.2 KiB]
# Operation completed over 1 objects/5.2 KiB.
# Pulling: HG03540
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/bd08e433-7896-4daa-a2ad-479ff6209407/call-alignAndGzip/HG03540.paf.gz...
# / [1 files][  6.2 KiB/  6.2 KiB]
# Operation completed over 1 objects/6.2 KiB.
# Pulling: HG03579
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/3173cf24-43fc-44b5-a6ae-de34de8ce60e/call-alignAndGzip/HG03579.paf.gz...
# / [1 files][  5.6 KiB/  5.6 KiB]
# Operation completed over 1 objects/5.6 KiB.
# Pulling: NA18906
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/919c8a34-9a99-4f8e-9b5b-e4d00e4e1855/call-alignAndGzip/NA18906.paf.gz...
# / [1 files][  542.0 B/  542.0 B]
# Operation completed over 1 objects/542.0 B.
# Pulling: NA19240
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/d989c583-7262-48c3-8df9-dd49a579b06b/call-alignAndGzip/NA19240.paf.gz...
# / [1 files][ 10.8 KiB/ 10.8 KiB]
# Operation completed over 1 objects/10.8 KiB.
# Pulling: NA20129
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/d19b0864-80fb-4b27-b69a-e9b1bd66afd9/minimap2/92e177eb-8bed-4ab3-964d-39793f3193e4/call-alignAndGzip/NA20129.paf.gz...
# / [1 files][  4.2 KiB/  4.2 KiB]
# Operation completed over 1 objects/4.2 KiB.
# Pulling: NA21309
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/
# 0   72.0    15.0  ms:i:15421  nn:i:1  s1:i:15755            HG02886  tp:A:P
# 0    4.0     0.0  ms:i:15441  nn:i:1  s1:i:15782            HG03098  tp:A:P
# 0   42.0    12.0  ms:i:15439  nn:i:1  s1:i:15793            HG03453  tp:A:P
# 0    3.0     1.0  ms:i:15378  nn:i:1  s1:i:15742            HG03486  tp:A:P
# 0    0.0     0.0  ms:i:15844  nn:i:1  s1:i:16020            HG03492  tp:A:P
# 0    2.0     0.0  ms:i:15359  nn:i:1  s1:i:15721            HG03516  tp:A:P
# 0    9.0     3.0  ms:i:15324  nn:i:1  s1:i:15658            HG03540  tp:A:P
# 0    9.0     3.0  ms:i:15253  nn:i:1  s1:i:15645            HG03579  tp:A:P
# 0    0.0     0.0  ms:i:14817  nn:i:1  s1:i:15383            NA18906  tp:A:P
# 0  124.0    38.0  ms:i:15762  nn:i:1  s1:i:16026            NA19240  tp:A:P
# 0    0.0     0.0  ms:i:15864  nn:i:1  s1:i:16064            NA20129  tp:A:P
# 0    6.0     2.0  ms:i:15299  nn:i:1  s1:i:15721            NA21309  tp:A:P
#
# [47 rows x 24 columns]

# %% [markdown]
# # Write MT Contigs

# %%
for index, row in clean_sample_df.iterrows():
    
    sample_name = row.name
    id_for_header = row['sample_name']
    
    ## Skip HG01701 because it doesn't have any MT contigs (known problem)
    if(sample_name == "HG01071"): 
        continue
        
    print(f"Pulling: {sample_name}")
    
    ## Download fasta with mito contigs
    mito_contig_fp = row['all_mito_contigs']
    
    ## Be sure to pull the manually rotated contigs when neccesary
    if sample_name == "HG02559":
        mito_contig_fp = "gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/mito_work/manually_rotated/HG02559.all_mito_contigs.fa"
        
    if sample_name == "HG03098":
        mito_contig_fp = "gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/mito_work/manually_rotated/HG03098.all_mito_contigs.fa"
    
    
    mito_contig_fn = os.path.basename(mito_contig_fp)

    ! gsutil cp {mito_contig_fp} ./
    
    
    ## Pull info about hit from dataframe with paf info for all samples
    is_sample = all_results_df['sample_name'] == sample_name
    
    seq_name        = all_results_df[is_sample]['Query_sequence_name'].values[0]
    seq_start       = all_results_df[is_sample]['Query_start'].values[0].astype('int32')
    seq_end         = all_results_df[is_sample]['Query_end'].values[0].astype('int32')
    is_minus_strand = all_results_df[is_sample]['Relative_strand'].values[0] == '-'
    

    ## Use pyfaidx to pull/write sequence 
    final_mito_contig_fn = f"{sample_name}.mt.fa"  
    mito_contgs = Fasta(mito_contig_fn)

    with open(final_mito_contig_fn, 'w') as final_mito_f:
        ## If hit (from minimap2) is on minus strand, we need to rev. compl. the sequence
        if(is_minus_strand):
            mito_entry = mito_contgs[seq_name][seq_start:seq_end].reverse.complement
        else:
            mito_entry = mito_contgs[seq_name][seq_start:seq_end]
        
        ## Write with expected contig naming structure
        # final_mito_f.write(f">{id_for_header}#2#MT\n")
        # final_mito_f.write(mito_entry.seq)
        
        record = SeqRecord(
            Seq(mito_entry.seq),
            id=f"{id_for_header}#2#MT",
            name=f"{id_for_header}#2#MT",
            description="")
        
        SeqIO.write(record, final_mito_f, "fasta")

    ## Copy up to bucket
    ! gsutil cp {final_mito_contig_fn} {bucket}corrected_mt_contig/{final_mito_contig_fn}
# Out:
# Pulling: HG002_downsampled
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/2ff987db-5231-49f3-9e89-a06c9cbd7df3/call-extractContigs/cacheCopy/HG002_downsampled.all_mito_contigs.fa...
# / [1 files][611.8 KiB/611.8 KiB]
# Operation completed over 1 objects/611.8 KiB.
# Copying file://HG002_downsampled.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG002_full_v0.14
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/26d0bbe2-4384-4e37-93ea-270f074dbbbe/call-extractContigs/cacheCopy/HG002_full_v0.14.all_mito_contigs.fa...
# / [1 files][  4.7 MiB/  4.7 MiB]
# Operation completed over 1 objects/4.7 MiB.
# Copying file://HG002_full_v0.14.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG00438
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/c7f935b8-5951-49bf-9d7e-574aff90ee98/call-extractContigs/cacheCopy/HG00438.all_mito_contigs.fa...
# / [1 files][ 65.4 KiB/ 65.4 KiB]
# Operation completed over 1 objects/65.4 KiB.
# Copying file://HG00438.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG005
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/2edc5105-4115-441c-a2a8-38878777bfc6/call-extractContigs/cacheCopy/HG005.all_mito_contigs.fa...
# / [1 files][  4.8 MiB/  4.8 MiB]
# Operation completed over 1 objects/4.8 MiB.
# Copying file://HG005.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG00621
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/ed544784-6218-4d5a-a846-9faa14635cb2/call-extractContigs/cacheCopy/HG00621.all_mito_contigs.fa...
# / [1 files][365.4 KiB/365.4 KiB]
# Operation completed over 1 objects/365.4 KiB.
# Copying file://HG00621.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG00673
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/324529a5-50ab-4d19-87b3-da875e8b9ca5/call-extractContigs/cacheCopy/HG00673.all_mito_contigs.fa...
# / [1 files][446.6 KiB/446.6 KiB]
# Operation completed over 1 objects/446.6 KiB.
# Copying file://HG00673.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG00733
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/ccf93a65-2fd0-4a93-a79c-4caf796b57a3/call-extractContigs/cacheCopy/HG00733.all_mito_contigs.fa...
# / [1 files][408.2 KiB/408.2 KiB]
# Operation completed over 1 objects/408.2 KiB.
# Copying file://HG00733.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG00735
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/0dc949f2-501d-4452-886e-c49cbe47e843/call-extractContigs/cacheCopy/HG00735.all_mito_contigs.fa...
# / [1 files][ 27.6 KiB/ 27.6 KiB]
# Operation completed over 1 objects/27.6 KiB.
# Copying file://HG00735.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG00741
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/17e7f8f0-4ccf-42d0-acb6-a92da6f72d26/call-extractContigs/cacheCopy/HG00741.all_mito_contigs.fa...
# / [1 files][ 46.1 KiB/ 46.1 KiB]
# Operation completed over 1 objects/46.1 KiB.
# Copying file://HG00741.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01106
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/631c71b6-7fb8-4676-81be-39886f29d7c5/call-extractContigs/cacheCopy/HG01106.all_mito_contigs.fa...
# / [1 files][ 65.4 KiB/ 65.4 KiB]
# Operation completed over 1 objects/65.4 KiB.
# Copying file://HG01106.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01109
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/8c515a8b-c1fa-40ca-bf01-751a67494a0b/call-extractContigs/cacheCopy/HG01109.all_mito_contigs.fa...
# / [1 files][102.0 KiB/102.0 KiB]
# Operation completed over 1 objects/102.0 KiB.
# Copying file://HG01109.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01123
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/81863f0b-409c-47cf-968f-7ad88d8f732d/call-extractContigs/cacheCopy/HG01123.all_mito_contigs.fa...
# / [1 files][789.2 KiB/789.2 KiB]
# Operation completed over 1 objects/789.2 KiB.
# Copying file://HG01123.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01175
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/b2799cea-218b-427b-a194-69ff81521f58/call-extractContigs/cacheCopy/HG01175.all_mito_contigs.fa...
# / [1 files][ 49.2 KiB/ 49.2 KiB]
# Operation completed over 1 objects/49.2 KiB.
# Copying file://HG01175.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01243
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/63e40a56-025c-4312-a1fb-95edabcdb37b/call-extractContigs/cacheCopy/HG01243.all_mito_contigs.fa...
# / [1 files][489.6 KiB/489.6 KiB]
# Operation completed over 1 objects/489.6 KiB.
# Copying file://HG01243.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01258
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/302512a7-6a8c-4222-83df-275f4c1a2424/call-extractContigs/cacheCopy/HG01258.all_mito_contigs.fa...
# / [1 files][828.4 KiB/828.4 KiB]
# Operation completed over 1 objects/828.4 KiB.
# Copying file://HG01258.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01358
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/2a09818c-a8a3-433d-a9ff-f51b9421c53a/call-extractContigs/cacheCopy/HG01358.all_mito_contigs.fa...
# / [1 files][  1.0 MiB/  1.0 MiB]
# Operation completed over 1 objects/1.0 MiB.
# Copying file://HG01358.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01361
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/7001bbcc-3eba-4046-a290-9e0bafca3527/call-extractContigs/cacheCopy/HG01361.all_mito_contigs.fa...
# / [1 files][505.4 KiB/505.4 KiB]
# Operation completed over 1 objects/505.4 KiB.
# Copying file://HG01361.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01891
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/5661fb20-8d01-4042-a712-7fbcf178092f/call-extractContigs/cacheCopy/HG01891.all_mito_contigs.fa...
# / [1 files][461.2 KiB/461.2 KiB]
# Operation completed over 1 objects/461.2 KiB.
# Copying file://HG01891.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01928
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/75b2cdc3-2b76-440d-89de-524a0643143a/call-extractContigs/cacheCopy/HG01928.all_mito_contigs.fa...
# / [1 files][ 64.3 KiB/ 64.3 KiB]
# Operation completed over 1 objects/64.3 KiB.
# Copying file://HG01928.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01952
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/86997e14-f7b2-4ca5-9241-9a98b45320d1/call-extractContigs/cacheCopy/HG01952.all_mito_contigs.fa...
# / [1 files][117.8 KiB/117.8 KiB]
# Operation completed over 1 objects/117.8 KiB.
# Copying file://HG01952.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG01978
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/fc9f2c16-36a1-465e-85bd-0f93f9b41ff5/call-extractContigs/cacheCopy/HG01978.all_mito_contigs.fa...
# / [1 files][ 32.6 KiB/ 32.6 KiB]
# Operation completed over 1 objects/32.6 KiB.
# Copying file://HG01978.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02055
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/2b68755e-2275-48b1-b6ab-8ca1ea99126d/call-extractContigs/cacheCopy/HG02055.all_mito_contigs.fa...
# / [1 files][739.1 KiB/739.1 KiB]
# Operation completed over 1 objects/739.1 KiB.
# Copying file://HG02055.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02080_split
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/0673e460-67ba-44e9-900c-0bdd940c51be/call-extractContigs/cacheCopy/HG02080_split.all_mito_contigs.fa...
# / [1 files][187.8 KiB/187.8 KiB]
# Operation completed over 1 objects/187.8 KiB.
# Copying file://HG02080_split.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02109
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/904e3b97-8741-4c91-ab7f-4a45619a244a/call-extractContigs/cacheCopy/HG02109.all_mito_contigs.fa...
# / [1 files][ 85.2 KiB/ 85.2 KiB]
# Operation completed over 1 objects/85.2 KiB.
# Copying file://HG02109.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02145
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/03228824-da50-4467-82a4-5e1151a24889/call-extractContigs/cacheCopy/HG02145.all_mito_contigs.fa...
# / [1 files][235.2 KiB/235.2 KiB]
# Operation completed over 1 objects/235.2 KiB.
# Copying file://HG02145.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02148
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/cd0ef80f-9af6-4e29-9397-8336427083b0/call-extractContigs/cacheCopy/HG02148.all_mito_contigs.fa...
# / [1 files][592.2 KiB/592.2 KiB]
# Operation completed over 1 objects/592.2 KiB.
# Copying file://HG02148.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02257
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/3df87f01-970b-4575-b0c4-cb1d944ff0ec/call-extractContigs/cacheCopy/HG02257.all_mito_contigs.fa...
# / [1 files][398.4 KiB/398.4 KiB]
# Operation completed over 1 objects/398.4 KiB.
# Copying file://HG02257.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02486
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/073b3bcb-879c-46cb-9620-b40e1c787ecb/call-extractContigs/cacheCopy/HG02486.all_mito_contigs.fa...
# / [1 files][738.2 KiB/738.2 KiB]
# Operation completed over 1 objects/738.2 KiB.
# Copying file://HG02486.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02559
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/mito_work/manually_rotated/HG02559.all_mito_contigs.fa...
# / [1 files][ 49.4 KiB/ 49.4 KiB]
# Operation completed over 1 objects/49.4 KiB.
# Copying file://HG02559.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02572
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/ff31061b-eec9-45a6-8de3-176397714e20/call-extractContigs/cacheCopy/HG02572.all_mito_contigs.fa...
# / [1 files][649.3 KiB/649.3 KiB]
# Operation completed over 1 objects/649.3 KiB.
# Copying file://HG02572.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02622
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/dc7961d8-7f11-40d9-b2b3-bbc3d9943ef7/call-extractContigs/cacheCopy/HG02622.all_mito_contigs.fa...
# / [1 files][ 38.5 KiB/ 38.5 KiB]
# Operation completed over 1 objects/38.5 KiB.
# Copying file://HG02622.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02630
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/a072fb0d-5679-40cf-8ba0-a636d1653fca/call-extractContigs/cacheCopy/HG02630.all_mito_contigs.fa...
# / [1 files][699.8 KiB/699.8 KiB]
# Operation completed over 1 objects/699.8 KiB.
# Copying file://HG02630.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02717
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/ee867948-8d60-4279-86bc-99c926f0b7b9/call-extractContigs/cacheCopy/HG02717.all_mito_contigs.fa...
# / [1 files][  1.2 MiB/  1.2 MiB]
# Operation completed over 1 objects/1.2 MiB.
# Copying file://HG02717.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02723
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/3f4b6e36-358b-4b95-bb2f-e949a2454bad/call-extractContigs/cacheCopy/HG02723.all_mito_contigs.fa...
# / [1 files][499.9 KiB/499.9 KiB]
# Operation completed over 1 objects/499.9 KiB.
# Copying file://HG02723.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02818
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/ff7552a1-e244-4fc9-ba80-d0e5e47dba1a/call-extractContigs/cacheCopy/HG02818.all_mito_contigs.fa...
# / [1 files][  1.3 MiB/  1.3 MiB]
# Operation completed over 1 objects/1.3 MiB.
# Copying file://HG02818.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG02886
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/a514a942-5656-48c4-8b45-f801f3259a7c/call-extractContigs/cacheCopy/HG02886.all_mito_contigs.fa...
# / [1 files][  1.4 MiB/  1.4 MiB]
# Operation completed over 1 objects/1.4 MiB.
# Copying file://HG02886.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG03098
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/mito_work/manually_rotated/HG03098.all_mito_contigs.fa...
# / [1 files][ 49.4 KiB/ 49.4 KiB]
# Operation completed over 1 objects/49.4 KiB.
# Copying file://HG03098.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG03453
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/a108c76d-b091-429d-9bba-d9f0efcc0449/call-extractContigs/cacheCopy/HG03453.all_mito_contigs.fa...
# / [1 files][529.8 KiB/529.8 KiB]
# Operation completed over 1 objects/529.8 KiB.
# Copying file://HG03453.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG03486
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/0feea9a3-b68d-4a43-9584-b529e97b8956/call-extractContigs/cacheCopy/HG03486.all_mito_contigs.fa...
# / [1 files][678.2 KiB/678.2 KiB]
# Operation completed over 1 objects/678.2 KiB.
# Copying file://HG03486.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG03492
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/aafc85da-671b-448a-bf63-876b4d47d1cf/call-extractContigs/cacheCopy/HG03492.all_mito_contigs.fa...
# / [1 files][379.5 KiB/379.5 KiB]
# Operation completed over 1 objects/379.5 KiB.
# Copying file://HG03492.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG03516
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/a0fd7f7b-cdcf-4b71-8859-eadc7043105b/call-extractContigs/cacheCopy/HG03516.all_mito_contigs.fa...
# / [1 files][419.4 KiB/419.4 KiB]
# Operation completed over 1 objects/419.4 KiB.
# Copying file://HG03516.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG03540
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/423c079c-25d3-4242-a8d2-67b64b1bd791/call-extractContigs/cacheCopy/HG03540.all_mito_contigs.fa...
# / [1 files][472.9 KiB/472.9 KiB]
# Operation completed over 1 objects/472.9 KiB.
# Copying file://HG03540.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: HG03579
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/352a6687-12e1-4589-8657-99c846e74093/call-extractContigs/cacheCopy/HG03579.all_mito_contigs.fa...
# / [1 files][493.6 KiB/493.6 KiB]
# Operation completed over 1 objects/493.6 KiB.
# Copying file://HG03579.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: NA18906
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/5b8a72aa-f22c-4c7b-80be-cbe851d2c044/call-extractContigs/cacheCopy/NA18906.all_mito_contigs.fa...
# / [1 files][ 64.5 KiB/ 64.5 KiB]
# Operation completed over 1 objects/64.5 KiB.
# Copying file://NA18906.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: NA19240
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/002f3c71-b9f6-4bc6-a002-a9d2fbd478f2/call-extractContigs/cacheCopy/NA19240.all_mito_contigs.fa...
# / [1 files][  1.3 MiB/  1.3 MiB]
# Operation completed over 1 objects/1.3 MiB.
# Copying file://NA19240.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: NA20129
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/f20f843b-d4ca-49c7-90f6-84bcb5c52aa9/call-extractContigs/cacheCopy/NA20129.all_mito_contigs.fa...
# / [1 files][435.6 KiB/435.6 KiB]
# Operation completed over 1 objects/435.6 KiB.
# Copying file://NA20129.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.
# Pulling: NA21309
# Copying gs://fc-0c2122a8-6725-4199-b90e-828ab006078f/85e90c15-bb68-4ea2-bfe2-56fd21fbb795/extractMitoContigs/44b95c81-1d56-49d1-9d0c-1efa2e0e98df/call-extractContigs/cacheCopy/NA21309.all_mito_contigs.fa...
# / [1 files][552.3 KiB/552.3 KiB]
# Operation completed over 1 objects/552.3 KiB.
# Copying file://NA21309.mt.fa [Content-Type=application/octet-stream]...
# / [1 files][ 16.5 KiB/ 16.5 KiB]
# Operation completed over 1 objects/16.5 KiB.

# %%
clean_sample_df['corrected_MT_contig'] = f"{bucket}corrected_mt_contig/" + clean_sample_df.index + ".mt.fa"

# %%
is_HG01071 = clean_sample_df['sample_name'] == "HG01071"

clean_sample_df.loc[is_HG01071, 'corrected_MT_contig'] = ""

# %%
upload_df = clean_sample_df[["sample_name", "mat_masked_cleaned_fa", "pat_masked_cleaned_fa", "corrected_MT_contig"]].copy()
upload_df = upload_df.rename(index={'1': 'corrected_sample_id'})

# %%
tp.dataframe_to_table("corrected_sample", upload_df)
